# %% [markdown]
# <a href="https://colab.research.google.com/github/Tom-Lennox/Kaggle/blob/master/HousePrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# title

# %%
# kaggle APIセット
# !pip install kaggle

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])

filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# 「Download 100%.」と表示で成功。

# [kaggle.json]を持参する。
from google.colab import drive
drive.mount('/content/drive')

# jsonファイルを指定の場所に配置
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# リスト見たい場合
# !kaggle datasets list

# train, test等ダウンロード
! kaggle competitions download house-prices-advanced-regression-techniques -p house-prices

# ダウンロードしたらここに入る大体。
# !ls /content/house-prices
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.11.28)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Download 100%.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# cp: cannot create regular file '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.
# ls: cannot access '/content/house-prices': No such file or directory

# %%
# jsonファイルを指定の場所に配置
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# リスト見たい場合
# !kaggle datasets list

# train, test等ダウンロード
! kaggle competitions download house-prices-advanced-regression-techniques -p house-prices

# ダウンロードしたらここに入る大体。
# !ls /content/house-prices
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading data_description.txt to house-prices
#   0% 0.00/13.1k [00:00<?, ?B/s]
# 100% 13.1k/13.1k [00:00<00:00, 5.17MB/s]
# Downloading sample_submission.csv to house-prices
#   0% 0.00/31.2k [00:00<?, ?B/s]
# 100% 31.2k/31.2k [00:00<00:00, 31.1MB/s]
# Downloading train.csv to house-prices
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 60.2MB/s]
# Downloading test.csv to house-prices
#   0% 0.00/441k [00:00<?, ?B/s]
# 100% 441k/441k [00:00<00:00, 84.0MB/s]
# data_description.txt  sample_submission.csv  test.csv  train.csv

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# とりあえずファイルを読み込む
train = pd.read_csv("/content/house-prices/train.csv")
test = pd.read_csv("/content/house-prices/test.csv")
# 読み込んだら確認したい
# train.head()
# test.head()

# array形式で確認したい場合（省略）
# print(np.array(test))
# 省略したくない場合は下記
# print('---')
# np.set_printoptions(threshold=np.inf)
# print(np.array(test))
# train.head(3)

# ==
# 配列の大きさを確認したい。
train['WhatIsData'] = 'Train'
test['WhatIsData'] = 'Test'
test['SalePrice'] = 9999999999
alldata = pd.concat([train,test],axis=0).reset_index(drop=True)
print('The size of train is : ' + str(train.shape))
print('The size of test is : ' + str(test.shape))
# ==
# train.info()

#  ■ わかること
# データ数：1460
# [Age, Cabin, Embarked]にnullあり。
# データ型が色々あること
# ⇒ dtypes: float64(3), int64(35), object(44)
# ==
# ■欠損値の確認
# （１つ１つpickしていくのは面倒。）
# pd.get_option("display.max_rows") # 行数取得
# pd.get_option("display.max_colwidth") # 列数取得

# ＝＝
# ■作業中■
# ■表示省略させない
# 下記はx（何で？）
# pd.set_option("display.max_rows", 80)
# pd.get_option("display.max_colwidth", 80)
# 下記はo（何で？）
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
# ＝＝
pd.options.display.max_columns = None
# print(pd.options.display.max_columns)
np.set_printoptions(threshold=np.inf)
# train.isnull()
# train.isnull().sum()

# ＝＝
# ■1以上のカラム名だけ取得できる。
# iteritems()
l = []
for index, value in train.isnull().sum().iteritems():
    if value > 0:
        l.append(index)
l
# 以下、駄文
# ■null等は勝手に埋めない。カラムの意味をしっかり把握する。
# nullに意味ある場合もある（a.g.　設備の有無等）
# ｜FLGを01で表現するか、nullで表現するかは場合による。

# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# ['LotFrontage,間口の広さ
#  'Alley',路地？
# Grvl    50  ？未舗装？
# Pave    41  舗装
#  'MasVnrType',？？の種類？柄か？壁？
# BrkCmn      15
# BrkFace    445
# None       864
# Stone      128
#  'MasVnrArea',？？の面積？庭？壁？壁か？
#  ⇒ 他の人の検索するとベニヤ板って書いてあるけど違うと思う。
# 0.0       861
# 1.0         2
# 11.0        1
# 14.0        1
# 16.0        7
#          ... 
# 1115.0      1
# 1129.0      1
# 1170.0      1
# 1378.0      1
# 1600.0      1
#  'BsmtQual',Bsmtの質？■Bsmtシリーズ。何これ？
#  ⇒ 評価っぽい。？劣化度合いとか？
# Ex    121
# Fa     35
# Gd    618
# TA    649
#  'BsmtCond',条件？condominium?
# 同上。
# Fa      45
# Gd      65
# Po       2
# TA    1311
#  'BsmtExposure',暴露?
#  ⇒ 向き！でもMnとかよくわからん。
# Av    221
# Gd    134
# Mn    114
# No    953
#  'BsmtFinType1',フィン？水かき？のタイプ
# QはQualityなのでは？
# ALQ    220
# BLQ    148
# GLQ    418
# LwQ     74
# Rec    133
# Unf    430
#  'BsmtFinType2',フィン？水かき？のタイプ2
#  ⇒ 「Unf」突然増えた。
# ALQ      19
# BLQ      33
# GLQ      14
# LwQ      46
# Rec      54
# Unf    1256
#  'Electrical',電気的？
# ヒューズ。契約か？
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# SBrkr    1334
#  'FireplaceQu',暖炉？
# Ex     24
# Fa     33
# Gd    380
# Po     20
# TA    313
#  'GarageType',ガレージ■ガレージ
# 2Types       6
# Attchd     870
# Basment     19
# BuiltIn     88
# CarPort      9
# Detchd     387
#  'GarageYrBlt',ガレージの？？
#  ⇒ 年っぽい。
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1910.0     3
# 1914.0     2
#           ..
# 2006.0    59
# 2007.0    49
# 2008.0    29
# 2009.0    21
# 2010.0     3
#  'GarageFinish',ガレージの仕上げ？
# Fin    352
# RFn    422
# Unf    605
#  'GarageQual',ガレージの質？
# Ex       3
# Fa      48
# Gd      14
# Po       3
# TA    1311
#  'GarageCond',ガレージのcondominium?
# Ex       2
# Fa      35
# Gd       9
# Po       7
# TA    1326
#  'PoolQC',プール？
# Ex    2
# Fa    2
# Gd    3
#  'Fence',フェンス？
# GdPrv     59
# GdWo      54
# MnPrv    157
# MnWw      11
#  'MiscFeature']その他の特徴
# Gar2     2
# Othr     2
# Shed    49
# TenC     1
# カラム単位のユニーク要素をカウント。
# sort_index()つけるとorder byできる。

# ！rowが多いから減らした。
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

train['LotShape'].value_counts().sort_index()
# ＝＝
# ■カラムと欠損値の内容を調べた。
# 次に
# 欠損値を埋める？
# 使う変数を選ぶ？
# Out:
# The size of train is : (1460, 82)
# The size of test is : (1459, 82)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# IR1    484
# IR2     41
# IR3     10
# Reg    925
# Name: LotShape, dtype: int64

# %%
# Street
# train.head(10)

# train.isnull().sum()
# train.dropna().shape

# 1460行
# Grvl    50
# Pave    41
# その他が 1460 - (50 + 41)
# train['Alley']
# train['Alley'].value_counts().sort_index()
# # ■NG;
# # 01に置き換える前に欠損値補填なんかできるわけない。
# train['Alley'] = train['Alley'].fillna(train['Alley'].medinan())

# train['Alley'][train['Alley'] == "Grvl"] = 0
train["Alley"][train["Alley"] == "Grvl"] = 0
# ■NG;
# intとstrだとカウントしてくれない。
# .sort_index()　を外せばok
# TypeError: '<' not supported between instances of 'str' and 'int'
train['Alley'].value_counts()
# 0       50
# Pave    41
# Grvlを0に。 ⇒ Paveを1に。
train["Alley"][train["Alley"] == "Pave"] = 1
train['Alley'].value_counts()
# 0    50
# 1    41
# ■dl
# 試しにmean()を入れてみる。
train['Alley'] = train['Alley'].fillna(train['Alley'].mean())
train['Alley'].value_counts()
# 0.450549    1369
# 0.000000      50
# 1.000000      41
# 01の評価に小数点以下は馬鹿っぽい。
# 下記にしたい。
# 舗装：1、砂利：2、路地ないよ：0
# リトライ
train = pd.read_csv("/content/house-prices/train.csv")
train["Alley"][train["Alley"] == "Grvl"] = 1
train["Alley"][train["Alley"] == "Pave"] = 2
train['Alley'] = train['Alley'].fillna(0)
train['Alley'].value_counts()

# ■重要そうな特徴量はどれ？
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    1369
# 1      50
# 2      41
# Name: Alley, dtype: int64

# %%
train.head(10)

# # カラム、リストに。
# train.columns  # カラム名一括請求
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# MSSubClass
# LotFrontage
# LotArea
# Alley
# OverallQual
# YearBuilt
# YearRemodAdd
# MasVnrArea
# ExterQual
# BsmtQual
# 1stFlrSF
# 2ndFlrSF
# KitchenQual
# Fireplaces
# GarageType
# GarageArea
# GarageQual
# PoolArea
# SaleCondition
# SalePrice
# カラム内、一意
train['MSSubClass'].unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40])

# %%
# train.head(10)

train.index    # index取得

# カラム、リストに。
train.columns  # カラム名一括請求

# pd.Series(train, name='MSSubClass').unique()

# 存在する要素をリストに
# 「目視確認」は馬鹿
train['Utilities'].value_counts()

# 型のみ
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley              int64
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# Heating           object
# HeatingQC         object
# CentralAir        object
# Electrical        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# dtype: object

# %%
train.head(3)

# ■わかること
# 特徴量
# Name, Ticketはめんどくさそう

#  ■ やること
# 欠損値を埋める
# [Sex, Embarked]　intに変える
# ｜平均値でいいかな
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave      0      Reg
# 1   2          20       RL         80.0     9600   Pave      0      Reg
# 2   3          60       RL         68.0    11250   Pave      0      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500

# %%
# 【他の人のコードを見たい】
# 大枠の流れ
# 価格　:left_right_arrow:　広さ、築年数、素材・完成度
# 各々、散布図、グラフ等で確認する
#  ⇒ 外れ値を除去していく。
# ■手順
# 1_
# EDA（探索的データ分析）
# 目的変数である家の価格の要約統計量を表示する
train["SalePrice"].describe()
# --
# mean
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# --
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer

# --
#家の価格（目的変数）、ヒストグラム
plt.figure(figsize=(20, 10))
sns.distplot(train['SalePrice'])
# plt.figure(figsize=(【縦幅px】, 【横幅px】))
# sns.distplot(【特徴量、グラフ表示する】)
# --
# --
#歪度と尖度を計算
print("歪度: %f" % train['SalePrice'].skew())
print("尖度: %f" % train['SalePrice'].kurt())
# 歪度と尖度
# 歪度：平均値と中央値のズレ（横ズレ）
# 尖度：平均付近の集まり具合（縦ズレ）
# --
test_x = pd.read_csv("/content/house-prices/test.csv")

# ---------------------------------
#物件の広さを合計した変数を作成
train["TotalSF"] = train["1stFlrSF"] + train["2ndFlrSF"] + train["TotalBsmtSF"]
test_x["TotalSF"] = test_x["1stFlrSF"] + test_x["2ndFlrSF"] + test_x["TotalBsmtSF"]
# TotalSF（新規作成）　に3項目の面積を代入
# ｜train, test_xに。

#物件の広さと物件価格の散布図を作成
plt.figure(figsize=(20, 10))# x:広さ, y:金額　で表現
plt.scatter(train["TotalSF"],train["SalePrice"])
plt.xlabel("TotalSF")
plt.ylabel("SalePrice")
# 広い方が高い（当然）

# ---------------------------------
#築年数と物件価格の散布図を作成
#plt.scatter(train["YearBuilt"],train["SalePrice"],color = "#E41A1C")
#plt.xlabel("YearBuilt")
#plt.ylabel("SalePrice")

data = pd.concat([train["YearBuilt"],train["SalePrice"]],axis=1)

plt.figure(figsize=(20, 10))
plt.xticks(rotation='90')
sns.boxplot(x="YearBuilt",y="SalePrice",data=data)
# 新しい方が高い（当然？）
# 外れ値 = ◆

# ↓

#外れ値を除外する
# ？（こんなアナログな方法で良いのか？）
# 外れ値と言えるのか？
train = train.drop(train[(train['YearBuilt']<2000) & (train['SalePrice']>600000)].index)

#グラフを描画する
data = pd.concat([train["YearBuilt"],train["SalePrice"]],axis=1)

plt.figure(figsize=(20, 10))
plt.xticks(rotation='90')
sns.boxplot(x="YearBuilt",y="SalePrice",data=data)
# ---------------------------------
# ---------------------------------
#家の材質・完成度と物件価格の散布図を作成
plt.figure(figsize=(20, 10))
plt.scatter(train["OverallQual"],train["SalePrice"])
plt.xlabel("OverallQual")
plt.ylabel("SalePrice")

# ↓

#外れ値を除外する
train = train.drop(train[(train['OverallQual']<5) & (train['SalePrice']>200000)].index)
train = train.drop(train[(train['OverallQual']<10) & (train['SalePrice']>500000)].index)

#グラフを描画する
plt.figure(figsize=(20, 10))
plt.scatter(train["OverallQual"],train["SalePrice"])
plt.xlabel("OverallQual")
plt.ylabel("SalePrice")
# ---------------------------------
# Out:
# 歪度: 1.882876
# 尖度: 6.536282
# Text(0, 0.5, 'SalePrice')

# %%
# 削除
train["SalePrice"].describe()
# Out:
# count      1451.000000
# mean     178478.937285
# std       72539.659266
# min       34900.000000
# 25%      129900.000000
# 50%      162500.000000
# 75%      213000.000000
# max      555000.000000
# Name: SalePrice, dtype: float64

# %%
#学習データを目的変数とそれ以外に分ける
train_x = train.drop("SalePrice",axis=1)
train_y = train["SalePrice"]

# ==
# 大枠の流れ
# 価格　:left_right_arrow:　広さ、築年数、素材・完成度
# 各々、散布図、グラフ等で確認する
#  ⇒ 外れ値を除去していく。
# 
# ？変数を分ける（学習データを目的変数とそれ以外に分ける）
# ？学習データとテストデータを統合
# データのサイズを確認
# データの欠損値を確認する
# 
# ==

#学習データとテストデータを統合
all_data = pd.concat([train_x,test_x],axis=0,sort=True)

#IDのカラムは不必要なので別の変数に格納
train_ID = train['Id']
test_ID = test_x['Id']

all_data.drop("Id", axis = 1, inplace = True)

#それぞれのデータのサイズを確認
print("train_x: "+str(train_x.shape))
print("train_y: "+str(train_y.shape))
print("test_x: "+str(test_x.shape))
print("all_data: "+str(all_data.shape))

#データの欠損値を確認する
all_data_na = all_data.isnull().sum()[all_data.isnull().sum()>0].sort_values(ascending=False)
all_data_na

#欠損値の数をグラフ化
plt.figure(figsize=(20,10))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)

# 欠損値があるカラムをリスト化
na_col_list = all_data.isnull().sum()[all_data.isnull().sum()>0].index.tolist()

#欠損があるカラムのデータ型を確認
all_data[na_col_list].dtypes.sort_values()
# Out:
# train_x: (1451, 81)
# train_y: (1451,)
# test_x: (1459, 81)
# all_data: (2910, 80)

# %%
# 欠損値があるカラムをリスト化
na_col_list = all_data.isnull().sum()[all_data.isnull().sum()>0].index.tolist()

#欠損があるカラムのデータ型を確認
all_data[na_col_list].dtypes.sort_values()
# Out:
# GarageArea      float64
# TotalBsmtSF     float64
# TotalSF         float64
# BsmtFinSF1      float64
# BsmtFinSF2      float64
# GarageYrBlt     float64
# BsmtFullBath    float64
# BsmtHalfBath    float64
# GarageCars      float64
# BsmtUnfSF       float64
# MasVnrArea      float64
# LotFrontage     float64
# GarageType       object
# KitchenQual      object
# MasVnrType       object
# MiscFeature      object
# PoolQC           object
# SaleType         object
# MSZoning         object
# GarageQual       object
# Alley            object
# GarageCond       object
# Functional       object
# FireplaceQu      object
# Fence            object
# Exterior2nd      object
# Exterior1st      object
# Electrical       object
# BsmtQual         object
# BsmtFinType2     object
# BsmtFinType1     object
# BsmtExposure     object
# BsmtCond         object
# GarageFinish     object
# Utilities        object
# dtype: object

# %%
#隣接した道路の長さ（LotFrontage）の欠損値の補完
all_data['LotFrontage'] = all_data.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

#欠損値が存在するかつfloat型のリストを作成
float_list = all_data[na_col_list].dtypes[all_data[na_col_list].dtypes == "float64"].index.tolist()

#欠損値が存在するかつobject型のリストを作成
obj_list = all_data[na_col_list].dtypes[all_data[na_col_list].dtypes == "object"].index.tolist()

#float型の場合は欠損値を0で置換
all_data[float_list] = all_data[float_list].fillna(0)

#object型の場合は欠損値を"None"で置換
all_data[obj_list] = all_data[obj_list].fillna("None")

#欠損値が全て置換できているか確認
all_data.isnull().sum()[all_data.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# カテゴリ変数に変換する
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %%
# --
# ■正規分布、SalesPrice

# 以下2同じ。対数取るだけ。
# ｜方法1
#目的変数の対数log(x+1)をとる
train_y = np.log1p(train_y)
#分布を可視化
# plt.figure(figsize=(20, 10))
# sns.distplot(train_y)

# ｜方法2
sns.distplot(np.log(train['SalePrice']))

# log
# 指定された double 値の自然対数値 (底は e) を返します。
# log1p
# 引数と 1 の合計の自然対数を返します。x の値が小さい場合、log1p(x) の結果は、log(1.0+x) の
# 浮動小数点評価よりも ln(1 + x) の真の結果にかなり近くなります。
# --

# %%
#数値の説明変数のリストを作成
num_feats = all_data.dtypes[all_data.dtypes != "object" ].index
# 目的変数
# ＝　予測したい変数
# 説明変数
# ＝　目的変数を説明する変数

#各説明変数の歪度を計算
skewed_feats = all_data[num_feats].apply(lambda x: x.skew()).sort_values(ascending = False)

#グラフ化
plt.figure(figsize=(20,10))
plt.xticks(rotation='90')
sns.barplot(x=skewed_feats.index, y=skewed_feats)
# 歪度の閾値は0.5として、それよりも歪度が大きいものは対数変換することにします。

# # --
# # ■Box-Cox変換
# # ｜プラスのみ。
# #歪度の絶対値が0.5より大きい変数だけに絞る
# skewed_feats_over = skewed_feats[abs(skewed_feats) > 0.5].index

# #各変数の最小値を表示
# for i in skewed_feats_over:
#     print(min(all_data[i]))
# # --
# --
#■Yeo-Johnson変換
# ｜マイナスにも可能。
pt = PowerTransformer()
pt.fit(all_data[skewed_feats_over])

#変換後のデータで各列を置換
all_data[skewed_feats_over] = pt.transform(all_data[skewed_feats_over])

#各説明変数の歪度を計算
skewed_feats_fixed = all_data[skewed_feats_over].apply(lambda x: x.skew()).sort_values(ascending = False)

#グラフ化
plt.figure(figsize=(20,10))
plt.xticks(rotation='90')
sns.barplot(x=skewed_feats_fixed.index, y=skewed_feats_fixed)
# --

# %%
#特徴量に1部屋あたりの面積を追加
all_data["FeetPerRoom"] =  all_data["TotalSF"]/all_data["TotRmsAbvGrd"]

#その他有効そうなものを追加する

#建築した年とリフォームした年の合計
all_data['YearBuiltAndRemod']=all_data['YearBuilt']+all_data['YearRemodAdd']

#バスルームの合計面積
all_data['Total_Bathrooms'] = (all_data['FullBath'] + (0.5 * all_data['HalfBath']) +
                               all_data['BsmtFullBath'] + (0.5 * all_data['BsmtHalfBath']))

#縁側の合計面積
all_data['Total_porch_sf'] = (all_data['OpenPorchSF'] + all_data['3SsnPorch'] +
                              all_data['EnclosedPorch'] + all_data['ScreenPorch'] +
                              all_data['WoodDeckSF'])

#プールの有無
all_data['haspool'] = all_data['PoolArea'].apply(lambda x: 1 if x > 0 else 0)

#2階の有無
all_data['has2ndfloor'] = all_data['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)

#ガレージの有無
all_data['hasgarage'] = all_data['GarageArea'].apply(lambda x: 1 if x > 0 else 0)

#地下室の有無
all_data['hasbsmt'] = all_data['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

#暖炉の有無
all_data['hasfireplace'] = all_data['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

# %%
# カテゴリ変数は多くのモデルでそのまま分析に用いることができません。
# そのため、カテゴリ変数をエンコーディングしていきます。
#各カラムのデータ型を確認
all_data.dtypes.value_counts()

#カテゴリ変数となっているカラムを取り出す
cal_list = all_data.dtypes[all_data.dtypes=="object"].index.tolist()

#学習データにおけるカテゴリ変数のデータ数を確認
train_x[cal_list].info()

# 学習データの中に数が0となっているカテゴリ変数はないようですのでそのまま進めていきます。

# --
# one-hot-encoding
# 各カテゴリ変数を（0,1）の二値変数をそれぞれ作成します。これらの二値変数は「ダミー変数」と呼ばれます。
#カテゴリ変数をget_dummiesによるone-hot-encodingを行う
all_data = pd.get_dummies(all_data,columns=cal_list)

#サイズを確認
all_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1451 entries, 0 to 1459
# Data columns (total 46 columns):
# Alley            1451 non-null int64
# BldgType         1451 non-null object
# BsmtCond         1414 non-null object
# BsmtExposure     1413 non-null object
# BsmtFinType1     1414 non-null object
# BsmtFinType2     1413 non-null object
# BsmtQual         1414 non-null object
# CentralAir       1451 non-null object
# Condition1       1451 non-null object
# Condition2       1451 non-null object
# Electrical       1450 non-null object
# ExterCond        1451 non-null object
# ExterQual        1451 non-null object
# Exterior1st      1451 non-null object
# Exterior2nd      1451 non-null object
# Fence            280 non-null object
# FireplaceQu      761 non-null object
# Foundation       1451 non-null object
# Functional       1451 non-null object
# GarageCond       1370 non-null object
# GarageFinish     1370 non-null object
# GarageQual       1370 non-null object
# GarageType       1370 non-null object
# Heating          1451 non-null object
# HeatingQC        1451 non-null object
# HouseStyle       1451 non-null object
# KitchenQual      1451 non-null object
# LandContour      1451 non-null object
# LandSlope        1451 non-null object
# LotConfig        1451 non-null object
# LotShape         1451 non-null object
# MSSubClass       1451 non-null int64
# MSZoning         1451 non-null object
# MasVnrType       1443 non-null object
# MiscFeature      54 non-null object
# MoSold           1451 non-null int64
# Neighborhood     1451 non-null object
# PavedDrive       1451 non-null object
# PoolQC           6 non-null object
# RoofMatl         1451 non-null object
# RoofStyle        1451 non-null object
# SaleCondition    1451 non-null object
# SaleType         1451 non-null object
# Street           1451 non-null object
# Utilities        1451 non-null object
# YrSold           1451 non-null int64
# dtypes: int64(4), object(42)
# memory usage: 532.8+ KB
# (2910, 353)

# %%
#学習データとテストデータに再分割
train_x = all_data.iloc[:train_x.shape[0],:].reset_index(drop=True)
test_x = all_data.iloc[train_x.shape[0]:,:].reset_index(drop=True)

#サイズを確認
print("train_x: "+str(train_x.shape))
print("test_x: "+str(test_x.shape))

from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb

# データの分割
train_x, valid_x, train_y, valid_y = train_test_split(
        train_x,
        train_y,
        test_size=0.3,
        random_state=0)

# --
# ■GBDT（勾配ブースティング木）によるモデル作成
#特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x,label=valid_y)

#パラメータを指定してGBDT
num_round = 5000
evallist = [(dvalid, 'eval'), (dtrain, 'train')]

evals_result = {}

#パラメータ
param = {
            'max_depth': 3,
            'eta': 0.01,
            'objective': 'reg:squarederror',
}

#学習の実行
bst = xgb.train(
  param, dtrain,
  num_round,
  evallist,
  evals_result=evals_result,
  # 一定ラウンド回しても改善が見込めない場合は学習を打ち切る
  early_stopping_rounds=1000
)
# 学習曲線を可視化する
plt.figure(figsize=(20, 10))
train_metric = evals_result['train']['rmse']
plt.plot(train_metric, label='train rmse')
eval_metric = evals_result['eval']['rmse']
plt.plot(eval_metric, label='eval rmse')
plt.grid()
plt.legend()
plt.xlabel('rounds')
plt.ylabel('rmse')
plt.ylim(0, 0.3)
plt.show()

#特徴量ごとの重要度を可視化する
ax = xgb.plot_importance(bst)
fig = ax.figure
fig.set_size_inches(10, 30)

# # あとはファイル作成
# import csv
# with open("predict_result_data_house.csv", "w") as f:
#   dtest = xgb.DMatrix(test_x)
#   my_submission = pd.DataFrame()
#   my_submission["Id"] = test_ID
#   my_submission["SalePrice"] = np.exp(bst.predict(dtest))
  
#   writer = csv.writer(f, lineterminator='\n')
#   # writer.writerow(["Id", "SalePrice"])
#   writer.writerow(["Id", "SalePrice"])  
#   for pid, survived in zip(test_data[:,0].astype(int), Y_pred.astype(int)):
#       writer.writerow([pid, survived])

# print('done');
# Out:
# train_x: (347, 353)
# test_x: (2563, 353)
# [0]	eval-rmse:0.249216	train-rmse:0.249209
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 1000 rounds.
# [1]	eval-rmse:0.246734	train-rmse:0.246728
# [2]	eval-rmse:0.244277	train-rmse:0.24427
# [3]	eval-rmse:0.241844	train-rmse:0.241838
# [4]	eval-rmse:0.239436	train-rmse:0.239429
# [5]	eval-rmse:0.237051	train-rmse:0.237045
# [6]	eval-rmse:0.234691	train-rmse:0.234684
# [7]	eval-rmse:0.232353	train-rmse:0.232347
# [8]	eval-rmse:0.230039	train-rmse:0.230033
# [9]	eval-rmse:0.227749	train-rmse:0.227742
# [10]	eval-rmse:0.225481	train-rmse:0.225474
# [11]	eval-rmse:0.223235	train-rmse:0.223229
# [12]	eval-rmse:0.221012	train-rmse:0.221006
# [13]	eval-rmse:0.218811	train-rmse:0.218805
# [14]	eval-rmse:0.216632	train-rmse:0.216626
# [15]	eval-rmse:0.214475	train-rmse:0.214468
# [16]	eval-rmse:0.212339	train-rmse:0.212333
# [17]	eval-rmse:0.210224	train-rmse:0.210218
# [18]	eval-rmse:0.208131	train-rmse:0.208124
# [19]	eval-rmse:0.206058	train-rmse:0.206052
# [20]	eval-rmse:0.204006	train-rmse:0.204
# [21]	eval-rmse:0.201974	train-rmse:0.201968
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [22]	eval-rmse:0.199963	train-rmse:0.199957
# [23]	eval-rmse:0.197972	train-rmse:0.197966
# [24]	eval-rmse:0.196	train-rmse:0.195994
# [25]	eval-rmse:0.194048	train-rmse:0.194042
# [26]	eval-rmse:0.192116	train-rmse:0.19211
# [27]	eval-rmse:0.190203	train-rmse:0.190197
# [28]	eval-rmse:0.188309	train-rmse:0.188302
# [29]	eval-rmse:0.186433	train-rmse:0.186427
# [30]	eval-rmse:0.184577	train-rmse:0.184571
# [31]	eval-rmse:0.182739	train-rmse:0.182732
# [32]	eval-rmse:0.180919	train-rmse:0.180913
# [33]	eval-rmse:0.179117	train-rmse:0.179111
# [34]	eval-rmse:0.177333	train-rmse:0.177327
# [35]	eval-rmse:0.175568	train-rmse:0.175561
# [36]	eval-rmse:0.173819	train-rmse:0.173813
# [37]	eval-rmse:0.172088	train-rmse:0.172082
# [38]	eval-rmse:0.170374	train-rmse:0.170368
# [39]	eval-rmse:0.168678	train-rmse:0.168672
# [40]	eval-rmse:0.166998	train-rmse:0.166992
# [41]	eval-rmse:0.165335	train-rmse:0.165329
# [42]	eval-rmse:0.163688	train-rmse:0.163682
# [43]	eval-rmse:0.162058	train-rmse:0.162052
# [44]	eval-rmse:0.160445	train-rmse:0.160438
# [45]	eval-rmse:0.158847	train-rmse:0.158841
# [46]	eval-rmse:0.157265	train-rmse:0.157259
# [47]	eval-rmse:0.155699	train-rmse:0.155693
# [48]	eval-rmse:0.154148	train-rmse:0.154142
# [49]	eval-rmse:0.152613	train-rmse:0.152607
# [50]	eval-rmse:0.151093	train-rmse:0.151087
# [51]	eval-rmse:0.149589	train-rmse:0.149583
# [52]	eval-rmse:0.148099	train-rmse:0.148093
# [53]	eval-rmse:0.146624	train-rmse:0.146618
# [54]	eval-rmse:0.145164	train-rmse:0.145158
# [55]	eval-rmse:0.143719	train-rmse:0.143712
# [56]	eval-rmse:0.142287	train-rmse:0.142281
# [57]	eval-rmse:0.14087	train-rmse:0.140864
# [58]	eval-rmse:0.139468	train-rmse:0.139461
# [59]	eval-rmse:0.138079	train-rmse:0.138072
# [60]	eval-rmse:0.136704	train-rmse:0.136697
# [61]	eval-rmse:0.135342	train-rmse:0.135336
# [62]	eval-rmse:0.133995	train-rmse:0.133988
# [63]	eval-rmse:0.13266	train-rmse:0.132654
# [64]	eval-rmse:0.131339	train-rmse:0.131333
# [65]	eval-rmse:0.130031	train-rmse:0.130025
# [66]	eval-rmse:0.128736	train-rmse:0.12873
# [67]	eval-rmse:0.127454	train-rmse:0.127448
# [68]	eval-rmse:0.126185	train-rmse:0.126179
# [69]	eval-rmse:0.124929	train-rmse:0.124922
# [70]	eval-rmse:0.123684	train-rmse:0.123678
# [71]	eval-rmse:0.122453	train-rmse:0.122447
# [72]	eval-rmse:0.121233	train-rmse:0.121227
# [73]	eval-rmse:0.120026	train-rmse:0.12002
# [74]	eval-rmse:0.118831	train-rmse:0.118825
# [75]	eval-rmse:0.117648	train-rmse:0.117641
# [76]	eval-rmse:0.116476	train-rmse:0.11647
# [77]	eval-rmse:0.115316	train-rmse:0.11531
# [78]	eval-rmse:0.114168	train-rmse:0.114161
# [79]	eval-rmse:0.113031	train-rmse:0.113025
# [80]	eval-rmse:0.111905	train-rmse:0.111899
# [81]	eval-rmse:0.110791	train-rmse:0.110785
# [82]	eval-rmse:0.109688	train-rmse:0.109681
# [83]	eval-rmse:0.108595	train-rmse:0.108589
# [84]	eval-rmse:0.107514	train-rmse:0.107508
# [85]	eval-rmse:0.106443	train-rmse:0.106437
# [86]	eval-rmse:0.105383	train-rmse:0.105377
# [87]	eval-rmse:0.104334	train-rmse:0.104328
# [88]	eval-rmse:0.103295	train-rmse:0.103289
# [89]	eval-rmse:0.102266	train-rmse:0.10226
# [90]	eval-rmse:0.101248	train-rmse:0.101242
# [91]	eval-rmse:0.10024	train-rmse:0.100234
# [92]	eval-rmse:0.099242	train-rmse:0.099235
# [93]	eval-rmse:0.098253	train-rmse:0.098247
# [94]	eval-rmse:0.097275	train-rmse:0.097269
# [95]	eval-rmse:0.096306	train-rmse:0.0963
# [96]	eval-rmse:0.095347	train-rmse:0.095341
# [97]	eval-rmse:0.094398	train-rmse:0.094391
# [98]	eval-rmse:0.093458	train-rmse:0.093451
# [99]	eval-rmse:0.092527	train-rmse:0.092521
# [100]	eval-rmse:0.091606	train-rmse:0.091599
# [101]	eval-rmse:0.090693	train-rmse:0.090687
# [102]	eval-rmse:0.08979	train-rmse:0.089784
# [103]	eval-rmse:0.088896	train-rmse:0.08889
# [104]	eval-rmse:0.088011	train-rmse:0.088005
# [105]	eval-rmse:0.087135	train-rmse:0.087128
# [106]	eval-rmse:0.086267	train-rmse:0.086261
# [107]	eval-rmse:0.085408	train-rmse:0.085402
# [108]	eval-rmse:0.084557	train-rmse:0.084551
# [109]	eval-rmse:0.083715	train-rmse:0.083709
# [110]	eval-rmse:0.082882	train-rmse:0.082875
# [111]	eval-rmse:0.082056	train-rmse:0.08205
# [112]	eval-rmse:0.081239	train-rmse:0.081233
# [113]	eval-rmse:0.08043	train-rmse:0.080424
# [114]	eval-rmse:0.079629	train-rmse:0.079623
# [115]	eval-rmse:0.078836	train-rmse:0.07883
# [116]	eval-rmse:0.078051	train-rmse:0.078045
# [117]	eval-rmse:0.077274	train-rmse:0.077268
# [118]	eval-rmse:0.076505	train-rmse:0.076498
# [119]	eval-rmse:0.075743	train-rmse:0.075737
# [120]	eval-rmse:0.074989	train-rmse:0.074982
# [121]	eval-rmse:0.074242	train-rmse:0.074236
# [122]	eval-rmse:0.073503	train-rmse:0.073496
# [123]	eval-rmse:0.072771	train-rmse:0.072764
# [124]	eval-rmse:0.072046	train-rmse:0.07204
# [125]	eval-rmse:0.071329	train-rmse:0.071322
# [126]	eval-rmse:0.070618	train-rmse:0.070612
# [127]	eval-rmse:0.069915	train-rmse:0.069909
# [128]	eval-rmse:0.069219	train-rmse:0.069213
# [129]	eval-rmse:0.06853	train-rmse:0.068523
# [130]	eval-rmse:0.067847	train-rmse:0.067841
# [131]	eval-rmse:0.067172	train-rmse:0.067165
# [132]	eval-rmse:0.066503	train-rmse:0.066497
# [133]	eval-rmse:0.065841	train-rmse:0.065834
# [134]	eval-rmse:0.065185	train-rmse:0.065179
# [135]	eval-rmse:0.064536	train-rmse:0.06453
# [136]	eval-rmse:0.063893	train-rmse:0.063887
# [137]	eval-rmse:0.063257	train-rmse:0.063251
# [138]	eval-rmse:0.062627	train-rmse:0.062621
# [139]	eval-rmse:0.062004	train-rmse:0.061997
# [140]	eval-rmse:0.061386	train-rmse:0.06138
# [141]	eval-rmse:0.060775	train-rmse:0.060769
# [142]	eval-rmse:0.06017	train-rmse:0.060164
# [143]	eval-rmse:0.059571	train-rmse:0.059564
# [144]	eval-rmse:0.058977	train-rmse:0.058971
# [145]	eval-rmse:0.05839	train-rmse:0.058384
# [146]	eval-rmse:0.057809	train-rmse:0.057803
# [147]	eval-rmse:0.057233	train-rmse:0.057227
# [148]	eval-rmse:0.056663	train-rmse:0.056657
# [149]	eval-rmse:0.056099	train-rmse:0.056093
# [150]	eval-rmse:0.05554	train-rmse:0.055534
# [151]	eval-rmse:0.054987	train-rmse:0.054981
# [152]	eval-rmse:0.05444	train-rmse:0.054434
# [153]	eval-rmse:0.053898	train-rmse:0.053892
# [154]	eval-rmse:0.053361	train-rmse:0.053355
# [155]	eval-rmse:0.05283	train-rmse:0.052824
# [156]	eval-rmse:0.052304	train-rmse:0.052298
# [157]	eval-rmse:0.051783	train-rmse:0.051777
# [158]	eval-rmse:0.051267	train-rmse:0.051261
# [159]	eval-rmse:0.050757	train-rmse:0.050751
# [160]	eval-rmse:0.050252	train-rmse:0.050245
# [161]	eval-rmse:0.049751	train-rmse:0.049745
# [162]	eval-rmse:0.049256	train-rmse:0.04925
# [163]	eval-rmse:0.048765	train-rmse:0.048759
# [164]	eval-rmse:0.04828	train-rmse:0.048274
# [165]	eval-rmse:0.047799	train-rmse:0.047793
# [166]	eval-rmse:0.047323	train-rmse:0.047317
# [167]	eval-rmse:0.046852	train-rmse:0.046846
# [168]	eval-rmse:0.046385	train-rmse:0.046379
# [169]	eval-rmse:0.045924	train-rmse:0.045917
# [170]	eval-rmse:0.045466	train-rmse:0.04546
# [171]	eval-rmse:0.045014	train-rmse:0.045007
# [172]	eval-rmse:0.044565	train-rmse:0.044559
# [173]	eval-rmse:0.044122	train-rmse:0.044116
# [174]	eval-rmse:0.043682	train-rmse:0.043676
# [175]	eval-rmse:0.043247	train-rmse:0.043241
# [176]	eval-rmse:0.042817	train-rmse:0.042811
# [177]	eval-rmse:0.042391	train-rmse:0.042384
# [178]	eval-rmse:0.041968	train-rmse:0.041962
# [179]	eval-rmse:0.041551	train-rmse:0.041544
# [180]	eval-rmse:0.041137	train-rmse:0.041131
# [181]	eval-rmse:0.040727	train-rmse:0.040721
# [182]	eval-rmse:0.040322	train-rmse:0.040316
# [183]	eval-rmse:0.03992	train-rmse:0.039914
# [184]	eval-rmse:0.039523	train-rmse:0.039517
# [185]	eval-rmse:0.039129	train-rmse:0.039123
# [186]	eval-rmse:0.03874	train-rmse:0.038734
# [187]	eval-rmse:0.038354	train-rmse:0.038348
# [188]	eval-rmse:0.037972	train-rmse:0.037966
# [189]	eval-rmse:0.037594	train-rmse:0.037588
# [190]	eval-rmse:0.03722	train-rmse:0.037214
# [191]	eval-rmse:0.036849	train-rmse:0.036843
# [192]	eval-rmse:0.036482	train-rmse:0.036476
# [193]	eval-rmse:0.036119	train-rmse:0.036113
# [194]	eval-rmse:0.03576	train-rmse:0.035754
# [195]	eval-rmse:0.035404	train-rmse:0.035397
# [196]	eval-rmse:0.035051	train-rmse:0.035045
# [197]	eval-rmse:0.034702	train-rmse:0.034696
# [198]	eval-rmse:0.034357	train-rmse:0.034351
# [199]	eval-rmse:0.034015	train-rmse:0.034009
# [200]	eval-rmse:0.033676	train-rmse:0.03367
# [201]	eval-rmse:0.033341	train-rmse:0.033335
# [202]	eval-rmse:0.033009	train-rmse:0.033003
# [203]	eval-rmse:0.03268	train-rmse:0.032674
# [204]	eval-rmse:0.032355	train-rmse:0.032349
# [205]	eval-rmse:0.032033	train-rmse:0.032027
# [206]	eval-rmse:0.031714	train-rmse:0.031708
# [207]	eval-rmse:0.031398	train-rmse:0.031392
# [208]	eval-rmse:0.031085	train-rmse:0.031079
# [209]	eval-rmse:0.030776	train-rmse:0.03077
# [210]	eval-rmse:0.03047	train-rmse:0.030463
# [211]	eval-rmse:0.030166	train-rmse:0.03016
# [212]	eval-rmse:0.029866	train-rmse:0.02986
# [213]	eval-rmse:0.029569	train-rmse:0.029563
# [214]	eval-rmse:0.029274	train-rmse:0.029268
# [215]	eval-rmse:0.028983	train-rmse:0.028977
# [216]	eval-rmse:0.028694	train-rmse:0.028688
# [217]	eval-rmse:0.028409	train-rmse:0.028403
# [218]	eval-rmse:0.028126	train-rmse:0.02812
# [219]	eval-rmse:0.027846	train-rmse:0.02784
# [220]	eval-rmse:0.027569	train-rmse:0.027563
# [221]	eval-rmse:0.027294	train-rmse:0.027288
# [222]	eval-rmse:0.027022	train-rmse:0.027016
# [223]	eval-rmse:0.026753	train-rmse:0.026747
# [224]	eval-rmse:0.026487	train-rmse:0.026481
# [225]	eval-rmse:0.026223	train-rmse:0.026217
# [226]	eval-rmse:0.025962	train-rmse:0.025956
# [227]	eval-rmse:0.025704	train-rmse:0.025698
# [228]	eval-rmse:0.025448	train-rmse:0.025442
# [229]	eval-rmse:0.025195	train-rmse:0.025189
# [230]	eval-rmse:0.024944	train-rmse:0.024938
# [231]	eval-rmse:0.024696	train-rmse:0.02469
# [232]	eval-rmse:0.02445	train-rmse:0.024444
# [233]	eval-rmse:0.024207	train-rmse:0.0242
# [234]	eval-rmse:0.023966	train-rmse:0.02396
# [235]	eval-rmse:0.023727	train-rmse:0.023721
# [236]	eval-rmse:0.023491	train-rmse:0.023485
# [237]	eval-rmse:0.023257	train-rmse:0.023251
# [238]	eval-rmse:0.023026	train-rmse:0.023019
# [239]	eval-rmse:0.022796	train-rmse:0.02279
# [240]	eval-rmse:0.022569	train-rmse:0.022563
# [241]	eval-rmse:0.022345	train-rmse:0.022339
# [242]	eval-rmse:0.022122	train-rmse:0.022116
# [243]	eval-rmse:0.021902	train-rmse:0.021896
# [244]	eval-rmse:0.021684	train-rmse:0.021678
# [245]	eval-rmse:0.021468	train-rmse:0.021462
# [246]	eval-rmse:0.021255	train-rmse:0.021249
# [247]	eval-rmse:0.021043	train-rmse:0.021037
# [248]	eval-rmse:0.020834	train-rmse:0.020828
# [249]	eval-rmse:0.020626	train-rmse:0.02062
# [250]	eval-rmse:0.020421	train-rmse:0.020415
# [251]	eval-rmse:0.020218	train-rmse:0.020212
# [252]	eval-rmse:0.020017	train-rmse:0.020011
# [253]	eval-rmse:0.019817	train-rmse:0.019811
# [254]	eval-rmse:0.01962	train-rmse:0.019614
# [255]	eval-rmse:0.019425	train-rmse:0.019419
# [256]	eval-rmse:0.019232	train-rmse:0.019226
# [257]	eval-rmse:0.01904	train-rmse:0.019034
# [258]	eval-rmse:0.018851	train-rmse:0.018845
# [259]	eval-rmse:0.018663	train-rmse:0.018657
# [260]	eval-rmse:0.018477	train-rmse:0.018471
# [261]	eval-rmse:0.018293	train-rmse:0.018287
# [262]	eval-rmse:0.018111	train-rmse:0.018105
# [263]	eval-rmse:0.017931	train-rmse:0.017925
# [264]	eval-rmse:0.017753	train-rmse:0.017747
# [265]	eval-rmse:0.017576	train-rmse:0.01757
# [266]	eval-rmse:0.017401	train-rmse:0.017395
# [267]	eval-rmse:0.017228	train-rmse:0.017222
# [268]	eval-rmse:0.017057	train-rmse:0.017051
# [269]	eval-rmse:0.016887	train-rmse:0.016881
# [270]	eval-rmse:0.016719	train-rmse:0.016713
# [271]	eval-rmse:0.016552	train-rmse:0.016547
# [272]	eval-rmse:0.016388	train-rmse:0.016382
# [273]	eval-rmse:0.016225	train-rmse:0.016219
# [274]	eval-rmse:0.016063	train-rmse:0.016057
# [275]	eval-rmse:0.015903	train-rmse:0.015898
# [276]	eval-rmse:0.015745	train-rmse:0.015739
# [277]	eval-rmse:0.015589	train-rmse:0.015583
# [278]	eval-rmse:0.015433	train-rmse:0.015428
# [279]	eval-rmse:0.01528	train-rmse:0.015274
# [280]	eval-rmse:0.015128	train-rmse:0.015122
# [281]	eval-rmse:0.014977	train-rmse:0.014971
# [282]	eval-rmse:0.014828	train-rmse:0.014822
# [283]	eval-rmse:0.014681	train-rmse:0.014675
# [284]	eval-rmse:0.014535	train-rmse:0.014529
# [285]	eval-rmse:0.01439	train-rmse:0.014384
# [286]	eval-rmse:0.014247	train-rmse:0.014241
# [287]	eval-rmse:0.014105	train-rmse:0.014099
# [288]	eval-rmse:0.013965	train-rmse:0.013959
# [289]	eval-rmse:0.013826	train-rmse:0.01382
# [290]	eval-rmse:0.013689	train-rmse:0.013683
# [291]	eval-rmse:0.013552	train-rmse:0.013547
# [292]	eval-rmse:0.013418	train-rmse:0.013412
# [293]	eval-rmse:0.013284	train-rmse:0.013278
# [294]	eval-rmse:0.013152	train-rmse:0.013146
# [295]	eval-rmse:0.013021	train-rmse:0.013015
# [296]	eval-rmse:0.012892	train-rmse:0.012886
# [297]	eval-rmse:0.012763	train-rmse:0.012758
# [298]	eval-rmse:0.012636	train-rmse:0.012631
# [299]	eval-rmse:0.012511	train-rmse:0.012505
# [300]	eval-rmse:0.012386	train-rmse:0.012381
# [301]	eval-rmse:0.012263	train-rmse:0.012257
# [302]	eval-rmse:0.012141	train-rmse:0.012135
# [303]	eval-rmse:0.012021	train-rmse:0.012015
# [304]	eval-rmse:0.011901	train-rmse:0.011895
# [305]	eval-rmse:0.011783	train-rmse:0.011777
# [306]	eval-rmse:0.011665	train-rmse:0.01166
# [307]	eval-rmse:0.011549	train-rmse:0.011544
# [308]	eval-rmse:0.011435	train-rmse:0.011429
# [309]	eval-rmse:0.011321	train-rmse:0.011315
# [310]	eval-rmse:0.011208	train-rmse:0.011203
# [311]	eval-rmse:0.011097	train-rmse:0.011091
# [312]	eval-rmse:0.010987	train-rmse:0.010981
# [313]	eval-rmse:0.010877	train-rmse:0.010872
# [314]	eval-rmse:0.010769	train-rmse:0.010764
# [315]	eval-rmse:0.010662	train-rmse:0.010656
# [316]	eval-rmse:0.010556	train-rmse:0.01055
# [317]	eval-rmse:0.010451	train-rmse:0.010446
# [318]	eval-rmse:0.010347	train-rmse:0.010342
# [319]	eval-rmse:0.010244	train-rmse:0.010239
# [320]	eval-rmse:0.010143	train-rmse:0.010137
# [321]	eval-rmse:0.010042	train-rmse:0.010036
# [322]	eval-rmse:0.009942	train-rmse:0.009936
# [323]	eval-rmse:0.009843	train-rmse:0.009838
# [324]	eval-rmse:0.009745	train-rmse:0.00974
# [325]	eval-rmse:0.009649	train-rmse:0.009643
# [326]	eval-rmse:0.009553	train-rmse:0.009547
# [327]	eval-rmse:0.009458	train-rmse:0.009452
# [328]	eval-rmse:0.009364	train-rmse:0.009358
# [329]	eval-rmse:0.009271	train-rmse:0.009265
# [330]	eval-rmse:0.009179	train-rmse:0.009173
# [331]	eval-rmse:0.009087	train-rmse:0.009082
# [332]	eval-rmse:0.008997	train-rmse:0.008991
# [333]	eval-rmse:0.008908	train-rmse:0.008902
# [334]	eval-rmse:0.008819	train-rmse:0.008814
# [335]	eval-rmse:0.008732	train-rmse:0.008726
# [336]	eval-rmse:0.008645	train-rmse:0.008639
# [337]	eval-rmse:0.008559	train-rmse:0.008553
# [338]	eval-rmse:0.008474	train-rmse:0.008468
# [339]	eval-rmse:0.00839	train-rmse:0.008384
# [340]	eval-rmse:0.008306	train-rmse:0.008301
# [341]	eval-rmse:0.008224	train-rmse:0.008218
# [342]	eval-rmse:0.008142	train-rmse:0.008137
# [343]	eval-rmse:0.008061	train-rmse:0.008056
# [344]	eval-rmse:0.007981	train-rmse:0.007976
# [345]	eval-rmse:0.007902	train-rmse:0.007897
# [346]	eval-rmse:0.007824	train-rmse:0.007818
# [347]	eval-rmse:0.007746	train-rmse:0.00774
# [348]	eval-rmse:0.007669	train-rmse:0.007664
# [349]	eval-rmse:0.007593	train-rmse:0.007587
# [350]	eval-rmse:0.007518	train-rmse:0.007512
# [351]	eval-rmse:0.007443	train-rmse:0.007437
# [352]	eval-rmse:0.007369	train-rmse:0.007364
# [353]	eval-rmse:0.007296	train-rmse:0.00729
# [354]	eval-rmse:0.007223	train-rmse:0.007218
# [355]	eval-rmse:0.007152	train-rmse:0.007146
# [356]	eval-rmse:0.007081	train-rmse:0.007075
# [357]	eval-rmse:0.00701	train-rmse:0.007005
# [358]	eval-rmse:0.006941	train-rmse:0.006936
# [359]	eval-rmse:0.006872	train-rmse:0.006867
# [360]	eval-rmse:0.006804	train-rmse:0.006798
# [361]	eval-rmse:0.006736	train-rmse:0.006731
# [362]	eval-rmse:0.00667	train-rmse:0.006664
# [363]	eval-rmse:0.006603	train-rmse:0.006598
# [364]	eval-rmse:0.006538	train-rmse:0.006533
# [365]	eval-rmse:0.006473	train-rmse:0.006468
# [366]	eval-rmse:0.006409	train-rmse:0.006404
# [367]	eval-rmse:0.006345	train-rmse:0.00634
# [368]	eval-rmse:0.006282	train-rmse:0.006277
# [369]	eval-rmse:0.00622	train-rmse:0.006215
# [370]	eval-rmse:0.006158	train-rmse:0.006153
# [371]	eval-rmse:0.006097	train-rmse:0.006092
# [372]	eval-rmse:0.006037	train-rmse:0.006032
# [373]	eval-rmse:0.005977	train-rmse:0.005972
# [374]	eval-rmse:0.005918	train-rmse:0.005913
# [375]	eval-rmse:0.005859	train-rmse:0.005854
# [376]	eval-rmse:0.005801	train-rmse:0.005796
# [377]	eval-rmse:0.005744	train-rmse:0.005738
# [378]	eval-rmse:0.005687	train-rmse:0.005681
# [379]	eval-rmse:0.00563	train-rmse:0.005625
# [380]	eval-rmse:0.005575	train-rmse:0.005569
# [381]	eval-rmse:0.005519	train-rmse:0.005514
# [382]	eval-rmse:0.005465	train-rmse:0.00546
# [383]	eval-rmse:0.005411	train-rmse:0.005405
# [384]	eval-rmse:0.005357	train-rmse:0.005352
# [385]	eval-rmse:0.005304	train-rmse:0.005299
# [386]	eval-rmse:0.005251	train-rmse:0.005246
# [387]	eval-rmse:0.005199	train-rmse:0.005194
# [388]	eval-rmse:0.005148	train-rmse:0.005143
# [389]	eval-rmse:0.005097	train-rmse:0.005092
# [390]	eval-rmse:0.005047	train-rmse:0.005041
# [391]	eval-rmse:0.004997	train-rmse:0.004992
# [392]	eval-rmse:0.004947	train-rmse:0.004942
# [393]	eval-rmse:0.004898	train-rmse:0.004893
# [394]	eval-rmse:0.00485	train-rmse:0.004845
# [395]	eval-rmse:0.004802	train-rmse:0.004797
# [396]	eval-rmse:0.004754	train-rmse:0.004749
# [397]	eval-rmse:0.004707	train-rmse:0.004702
# [398]	eval-rmse:0.004661	train-rmse:0.004656
# [399]	eval-rmse:0.004615	train-rmse:0.00461
# [400]	eval-rmse:0.004569	train-rmse:0.004564
# [401]	eval-rmse:0.004524	train-rmse:0.004519
# [402]	eval-rmse:0.004479	train-rmse:0.004474
# [403]	eval-rmse:0.004435	train-rmse:0.00443
# [404]	eval-rmse:0.004391	train-rmse:0.004386
# [405]	eval-rmse:0.004348	train-rmse:0.004343
# [406]	eval-rmse:0.004305	train-rmse:0.0043
# [407]	eval-rmse:0.004262	train-rmse:0.004258
# [408]	eval-rmse:0.00422	train-rmse:0.004215
# [409]	eval-rmse:0.004179	train-rmse:0.004174
# [410]	eval-rmse:0.004137	train-rmse:0.004133
# [411]	eval-rmse:0.004097	train-rmse:0.004092
# [412]	eval-rmse:0.004056	train-rmse:0.004051
# [413]	eval-rmse:0.004016	train-rmse:0.004011
# [414]	eval-rmse:0.003977	train-rmse:0.003972
# [415]	eval-rmse:0.003937	train-rmse:0.003933
# [416]	eval-rmse:0.003899	train-rmse:0.003894
# [417]	eval-rmse:0.00386	train-rmse:0.003855
# [418]	eval-rmse:0.003822	train-rmse:0.003817
# [419]	eval-rmse:0.003784	train-rmse:0.00378
# [420]	eval-rmse:0.003747	train-rmse:0.003742
# [421]	eval-rmse:0.00371	train-rmse:0.003706
# [422]	eval-rmse:0.003674	train-rmse:0.003669
# [423]	eval-rmse:0.003638	train-rmse:0.003633
# [424]	eval-rmse:0.003602	train-rmse:0.003597
# [425]	eval-rmse:0.003566	train-rmse:0.003562
# [426]	eval-rmse:0.003531	train-rmse:0.003527
# [427]	eval-rmse:0.003497	train-rmse:0.003492
# [428]	eval-rmse:0.003462	train-rmse:0.003458
# [429]	eval-rmse:0.003428	train-rmse:0.003424
# [430]	eval-rmse:0.003394	train-rmse:0.00339
# [431]	eval-rmse:0.003361	train-rmse:0.003357
# [432]	eval-rmse:0.003328	train-rmse:0.003324
# [433]	eval-rmse:0.003295	train-rmse:0.003291
# [434]	eval-rmse:0.003263	train-rmse:0.003259
# [435]	eval-rmse:0.003231	train-rmse:0.003227
# [436]	eval-rmse:0.003199	train-rmse:0.003195
# [437]	eval-rmse:0.003168	train-rmse:0.003163
# [438]	eval-rmse:0.003137	train-rmse:0.003132
# [439]	eval-rmse:0.003106	train-rmse:0.003102
# [440]	eval-rmse:0.003076	train-rmse:0.003071
# [441]	eval-rmse:0.003045	train-rmse:0.003041
# [442]	eval-rmse:0.003016	train-rmse:0.003011
# [443]	eval-rmse:0.002986	train-rmse:0.002982
# [444]	eval-rmse:0.002957	train-rmse:0.002953
# [445]	eval-rmse:0.002928	train-rmse:0.002924
# [446]	eval-rmse:0.002899	train-rmse:0.002895
# [447]	eval-rmse:0.002871	train-rmse:0.002867
# [448]	eval-rmse:0.002843	train-rmse:0.002839
# [449]	eval-rmse:0.002815	train-rmse:0.002811
# [450]	eval-rmse:0.002787	train-rmse:0.002783
# [451]	eval-rmse:0.00276	train-rmse:0.002756
# [452]	eval-rmse:0.002733	train-rmse:0.002729
# [453]	eval-rmse:0.002707	train-rmse:0.002703
# [454]	eval-rmse:0.00268	train-rmse:0.002676
# [455]	eval-rmse:0.002654	train-rmse:0.00265
# [456]	eval-rmse:0.002628	train-rmse:0.002624
# [457]	eval-rmse:0.002603	train-rmse:0.002599
# [458]	eval-rmse:0.002577	train-rmse:0.002573
# [459]	eval-rmse:0.002552	train-rmse:0.002548
# [460]	eval-rmse:0.002527	train-rmse:0.002523
# [461]	eval-rmse:0.002503	train-rmse:0.002499
# [462]	eval-rmse:0.002478	train-rmse:0.002475
# [463]	eval-rmse:0.002454	train-rmse:0.002451
# [464]	eval-rmse:0.00243	train-rmse:0.002427
# [465]	eval-rmse:0.002407	train-rmse:0.002403
# [466]	eval-rmse:0.002384	train-rmse:0.00238
# [467]	eval-rmse:0.00236	train-rmse:0.002357
# [468]	eval-rmse:0.002338	train-rmse:0.002334
# [469]	eval-rmse:0.002315	train-rmse:0.002311
# [470]	eval-rmse:0.002292	train-rmse:0.002289
# [471]	eval-rmse:0.00227	train-rmse:0.002267
# [472]	eval-rmse:0.002248	train-rmse:0.002245
# [473]	eval-rmse:0.002227	train-rmse:0.002223
# [474]	eval-rmse:0.002205	train-rmse:0.002201
# [475]	eval-rmse:0.002184	train-rmse:0.00218
# [476]	eval-rmse:0.002163	train-rmse:0.002159
# [477]	eval-rmse:0.002142	train-rmse:0.002138
# [478]	eval-rmse:0.002121	train-rmse:0.002118
# [479]	eval-rmse:0.002101	train-rmse:0.002097
# [480]	eval-rmse:0.00208	train-rmse:0.002077
# [481]	eval-rmse:0.00206	train-rmse:0.002057
# [482]	eval-rmse:0.002041	train-rmse:0.002037
# [483]	eval-rmse:0.002021	train-rmse:0.002018
# [484]	eval-rmse:0.002002	train-rmse:0.001998
# [485]	eval-rmse:0.001982	train-rmse:0.001979
# [486]	eval-rmse:0.001963	train-rmse:0.00196
# [487]	eval-rmse:0.001944	train-rmse:0.001941
# [488]	eval-rmse:0.001926	train-rmse:0.001923
# [489]	eval-rmse:0.001907	train-rmse:0.001904
# [490]	eval-rmse:0.001889	train-rmse:0.001886
# [491]	eval-rmse:0.001871	train-rmse:0.001868
# [492]	eval-rmse:0.001853	train-rmse:0.00185
# [493]	eval-rmse:0.001836	train-rmse:0.001833
# [494]	eval-rmse:0.001818	train-rmse:0.001815
# [495]	eval-rmse:0.001801	train-rmse:0.001798
# [496]	eval-rmse:0.001784	train-rmse:0.001781
# [497]	eval-rmse:0.001767	train-rmse:0.001764
# [498]	eval-rmse:0.00175	train-rmse:0.001747
# [499]	eval-rmse:0.001733	train-rmse:0.001731
# [500]	eval-rmse:0.001717	train-rmse:0.001714
# [501]	eval-rmse:0.001701	train-rmse:0.001698
# [502]	eval-rmse:0.001684	train-rmse:0.001682
# [503]	eval-rmse:0.001668	train-rmse:0.001666
# [504]	eval-rmse:0.001653	train-rmse:0.00165
# [505]	eval-rmse:0.001637	train-rmse:0.001635
# [506]	eval-rmse:0.001622	train-rmse:0.001619
# [507]	eval-rmse:0.001606	train-rmse:0.001604
# [508]	eval-rmse:0.001591	train-rmse:0.001589
# [509]	eval-rmse:0.001576	train-rmse:0.001574
# [510]	eval-rmse:0.001561	train-rmse:0.001559
# [511]	eval-rmse:0.001547	train-rmse:0.001545
# [512]	eval-rmse:0.001532	train-rmse:0.00153
# [513]	eval-rmse:0.001518	train-rmse:0.001516
# [514]	eval-rmse:0.001504	train-rmse:0.001502
# [515]	eval-rmse:0.00149	train-rmse:0.001488
# [516]	eval-rmse:0.001476	train-rmse:0.001474
# [517]	eval-rmse:0.001462	train-rmse:0.00146
# [518]	eval-rmse:0.001449	train-rmse:0.001447
# [519]	eval-rmse:0.001435	train-rmse:0.001433
# [520]	eval-rmse:0.001422	train-rmse:0.00142
# [521]	eval-rmse:0.001409	train-rmse:0.001407
# [522]	eval-rmse:0.001396	train-rmse:0.001394
# [523]	eval-rmse:0.001383	train-rmse:0.001381
# [524]	eval-rmse:0.00137	train-rmse:0.001368
# [525]	eval-rmse:0.001357	train-rmse:0.001356
# [526]	eval-rmse:0.001345	train-rmse:0.001343
# [527]	eval-rmse:0.001332	train-rmse:0.001331
# [528]	eval-rmse:0.00132	train-rmse:0.001319
# [529]	eval-rmse:0.001308	train-rmse:0.001307
# [530]	eval-rmse:0.001296	train-rmse:0.001295
# [531]	eval-rmse:0.001284	train-rmse:0.001283
# [532]	eval-rmse:0.001273	train-rmse:0.001271
# [533]	eval-rmse:0.001261	train-rmse:0.00126
# [534]	eval-rmse:0.001249	train-rmse:0.001248
# [535]	eval-rmse:0.001238	train-rmse:0.001237
# [536]	eval-rmse:0.001227	train-rmse:0.001226
# [537]	eval-rmse:0.001216	train-rmse:0.001215
# [538]	eval-rmse:0.001205	train-rmse:0.001204
# [539]	eval-rmse:0.001194	train-rmse:0.001193
# [540]	eval-rmse:0.001183	train-rmse:0.001182
# [541]	eval-rmse:0.001173	train-rmse:0.001172
# [542]	eval-rmse:0.001162	train-rmse:0.001161
# [543]	eval-rmse:0.001152	train-rmse:0.001151
# [544]	eval-rmse:0.001142	train-rmse:0.001141
# [545]	eval-rmse:0.001131	train-rmse:0.001131
# [546]	eval-rmse:0.001121	train-rmse:0.001121
# [547]	eval-rmse:0.001111	train-rmse:0.001111
# [548]	eval-rmse:0.001102	train-rmse:0.001101
# [549]	eval-rmse:0.001092	train-rmse:0.001091
# [550]	eval-rmse:0.001082	train-rmse:0.001082
# [551]	eval-rmse:0.001073	train-rmse:0.001072
# [552]	eval-rmse:0.001063	train-rmse:0.001063
# [553]	eval-rmse:0.001054	train-rmse:0.001054
# [554]	eval-rmse:0.001045	train-rmse:0.001045
# [555]	eval-rmse:0.001036	train-rmse:0.001036
# [556]	eval-rmse:0.001027	train-rmse:0.001027
# [557]	eval-rmse:0.001018	train-rmse:0.001018
# [558]	eval-rmse:0.001009	train-rmse:0.001009
# [559]	eval-rmse:0.001	train-rmse:0.001
# [560]	eval-rmse:0.000992	train-rmse:0.000992
# [561]	eval-rmse:0.000983	train-rmse:0.000983
# [562]	eval-rmse:0.000975	train-rmse:0.000975
# [563]	eval-rmse:0.000967	train-rmse:0.000967
# [564]	eval-rmse:0.000958	train-rmse:0.000959
# [565]	eval-rmse:0.00095	train-rmse:0.000951
# [566]	eval-rmse:0.000942	train-rmse:0.000943
# [567]	eval-rmse:0.000934	train-rmse:0.000935
# [568]	eval-rmse:0.000926	train-rmse:0.000927
# [569]	eval-rmse:0.000919	train-rmse:0.000919
# [570]	eval-rmse:0.000911	train-rmse:0.000912
# [571]	eval-rmse:0.000903	train-rmse:0.000904
# [572]	eval-rmse:0.000896	train-rmse:0.000897
# [573]	eval-rmse:0.000889	train-rmse:0.000889
# [574]	eval-rmse:0.000881	train-rmse:0.000882
# [575]	eval-rmse:0.000874	train-rmse:0.000875
# [576]	eval-rmse:0.000867	train-rmse:0.000868
# [577]	eval-rmse:0.00086	train-rmse:0.000861
# [578]	eval-rmse:0.000853	train-rmse:0.000854
# [579]	eval-rmse:0.000846	train-rmse:0.000847
# [580]	eval-rmse:0.000839	train-rmse:0.00084
# [581]	eval-rmse:0.000832	train-rmse:0.000834
# [582]	eval-rmse:0.000826	train-rmse:0.000827
# [583]	eval-rmse:0.000819	train-rmse:0.00082
# [584]	eval-rmse:0.000813	train-rmse:0.000814
# [585]	eval-rmse:0.000806	train-rmse:0.000808
# [586]	eval-rmse:0.0008	train-rmse:0.000801
# [587]	eval-rmse:0.000793	train-rmse:0.000795
# [588]	eval-rmse:0.000787	train-rmse:0.000789
# [589]	eval-rmse:0.000781	train-rmse:0.000783
# [590]	eval-rmse:0.000775	train-rmse:0.000777
# [591]	eval-rmse:0.000769	train-rmse:0.000771
# [592]	eval-rmse:0.000763	train-rmse:0.000765
# [593]	eval-rmse:0.000757	train-rmse:0.000759
# [594]	eval-rmse:0.000752	train-rmse:0.000753
# [595]	eval-rmse:0.000746	train-rmse:0.000748
# [596]	eval-rmse:0.00074	train-rmse:0.000742
# [597]	eval-rmse:0.000735	train-rmse:0.000737
# [598]	eval-rmse:0.000729	train-rmse:0.000731
# [599]	eval-rmse:0.000724	train-rmse:0.000726
# [600]	eval-rmse:0.000718	train-rmse:0.00072
# [601]	eval-rmse:0.000713	train-rmse:0.000715
# [602]	eval-rmse:0.000708	train-rmse:0.00071
# [603]	eval-rmse:0.000703	train-rmse:0.000705
# [604]	eval-rmse:0.000698	train-rmse:0.0007
# [605]	eval-rmse:0.000693	train-rmse:0.000695
# [606]	eval-rmse:0.000688	train-rmse:0.00069
# [607]	eval-rmse:0.000683	train-rmse:0.000685
# [608]	eval-rmse:0.000678	train-rmse:0.00068
# [609]	eval-rmse:0.000673	train-rmse:0.000676
# [610]	eval-rmse:0.000668	train-rmse:0.000671
# [611]	eval-rmse:0.000664	train-rmse:0.000666
# [612]	eval-rmse:0.000659	train-rmse:0.000662
# [613]	eval-rmse:0.000655	train-rmse:0.000657
# [614]	eval-rmse:0.00065	train-rmse:0.000653
# [615]	eval-rmse:0.000646	train-rmse:0.000649
# [616]	eval-rmse:0.000641	train-rmse:0.000644
# [617]	eval-rmse:0.000637	train-rmse:0.00064
# [618]	eval-rmse:0.000633	train-rmse:0.000636
# [619]	eval-rmse:0.000629	train-rmse:0.000632
# [620]	eval-rmse:0.000625	train-rmse:0.000627
# [621]	eval-rmse:0.00062	train-rmse:0.000623
# [622]	eval-rmse:0.000616	train-rmse:0.000619
# [623]	eval-rmse:0.000612	train-rmse:0.000616
# [624]	eval-rmse:0.000609	train-rmse:0.000612
# [625]	eval-rmse:0.000605	train-rmse:0.000608
# [626]	eval-rmse:0.000601	train-rmse:0.000604
# [627]	eval-rmse:0.000597	train-rmse:0.0006
# [628]	eval-rmse:0.000593	train-rmse:0.000597
# [629]	eval-rmse:0.00059	train-rmse:0.000593
# [630]	eval-rmse:0.000586	train-rmse:0.00059
# [631]	eval-rmse:0.000583	train-rmse:0.000586
# [632]	eval-rmse:0.000579	train-rmse:0.000583
# [633]	eval-rmse:0.000576	train-rmse:0.000579
# [634]	eval-rmse:0.000572	train-rmse:0.000576
# [635]	eval-rmse:0.000569	train-rmse:0.000572
# [636]	eval-rmse:0.000566	train-rmse:0.000569
# [637]	eval-rmse:0.000562	train-rmse:0.000566
# [638]	eval-rmse:0.000559	train-rmse:0.000563
# [639]	eval-rmse:0.000556	train-rmse:0.000559
# [640]	eval-rmse:0.000553	train-rmse:0.000556
# [641]	eval-rmse:0.00055	train-rmse:0.000553
# [642]	eval-rmse:0.000547	train-rmse:0.00055
# [643]	eval-rmse:0.000544	train-rmse:0.000547
# [644]	eval-rmse:0.000541	train-rmse:0.000544
# [645]	eval-rmse:0.000538	train-rmse:0.000542
# [646]	eval-rmse:0.000535	train-rmse:0.000539
# [647]	eval-rmse:0.000532	train-rmse:0.000536
# [648]	eval-rmse:0.000529	train-rmse:0.000533
# [649]	eval-rmse:0.000526	train-rmse:0.00053
# [650]	eval-rmse:0.000524	train-rmse:0.000528
# [651]	eval-rmse:0.000521	train-rmse:0.000525
# [652]	eval-rmse:0.000518	train-rmse:0.000523
# [653]	eval-rmse:0.000516	train-rmse:0.00052
# [654]	eval-rmse:0.000513	train-rmse:0.000517
# [655]	eval-rmse:0.000511	train-rmse:0.000515
# [656]	eval-rmse:0.000508	train-rmse:0.000512
# [657]	eval-rmse:0.000506	train-rmse:0.00051
# [658]	eval-rmse:0.000504	train-rmse:0.000508
# [659]	eval-rmse:0.000501	train-rmse:0.000505
# [660]	eval-rmse:0.000499	train-rmse:0.000503
# [661]	eval-rmse:0.000496	train-rmse:0.000501
# [662]	eval-rmse:0.000494	train-rmse:0.000499
# [663]	eval-rmse:0.000492	train-rmse:0.000496
# [664]	eval-rmse:0.00049	train-rmse:0.000494
# [665]	eval-rmse:0.000488	train-rmse:0.000492
# [666]	eval-rmse:0.000486	train-rmse:0.00049
# [667]	eval-rmse:0.000483	train-rmse:0.000488
# [668]	eval-rmse:0.000481	train-rmse:0.000486
# [669]	eval-rmse:0.000479	train-rmse:0.000484
# [670]	eval-rmse:0.000477	train-rmse:0.000482
# [671]	eval-rmse:0.000475	train-rmse:0.00048
# [672]	eval-rmse:0.000473	train-rmse:0.000478
# [673]	eval-rmse:0.000472	train-rmse:0.000476
# [674]	eval-rmse:0.00047	train-rmse:0.000474
# [675]	eval-rmse:0.000468	train-rmse:0.000472
# [676]	eval-rmse:0.000466	train-rmse:0.000471
# [677]	eval-rmse:0.000464	train-rmse:0.000469
# [678]	eval-rmse:0.000462	train-rmse:0.000467
# [679]	eval-rmse:0.000461	train-rmse:0.000466
# [680]	eval-rmse:0.000459	train-rmse:0.000464
# [681]	eval-rmse:0.000457	train-rmse:0.000462
# [682]	eval-rmse:0.000456	train-rmse:0.00046
# [683]	eval-rmse:0.000454	train-rmse:0.000459
# [684]	eval-rmse:0.000453	train-rmse:0.000457
# [685]	eval-rmse:0.000451	train-rmse:0.000456
# [686]	eval-rmse:0.000449	train-rmse:0.000454
# [687]	eval-rmse:0.000448	train-rmse:0.000453
# [688]	eval-rmse:0.000446	train-rmse:0.000451
# [689]	eval-rmse:0.000445	train-rmse:0.00045
# [690]	eval-rmse:0.000443	train-rmse:0.000448
# [691]	eval-rmse:0.000442	train-rmse:0.000447
# [692]	eval-rmse:0.000441	train-rmse:0.000446
# [693]	eval-rmse:0.000439	train-rmse:0.000444
# [694]	eval-rmse:0.000438	train-rmse:0.000443
# [695]	eval-rmse:0.000437	train-rmse:0.000442
# [696]	eval-rmse:0.000435	train-rmse:0.00044
# [697]	eval-rmse:0.000434	train-rmse:0.000439
# [698]	eval-rmse:0.000433	train-rmse:0.000438
# [699]	eval-rmse:0.000431	train-rmse:0.000437
# [700]	eval-rmse:0.00043	train-rmse:0.000435
# [701]	eval-rmse:0.000429	train-rmse:0.000434
# [702]	eval-rmse:0.000428	train-rmse:0.000433
# [703]	eval-rmse:0.000427	train-rmse:0.000432
# [704]	eval-rmse:0.000426	train-rmse:0.000431
# [705]	eval-rmse:0.000424	train-rmse:0.00043
# [706]	eval-rmse:0.000423	train-rmse:0.000429
# [707]	eval-rmse:0.000422	train-rmse:0.000428
# [708]	eval-rmse:0.000421	train-rmse:0.000427
# [709]	eval-rmse:0.00042	train-rmse:0.000426
# [710]	eval-rmse:0.000419	train-rmse:0.000424
# [711]	eval-rmse:0.000418	train-rmse:0.000423
# [712]	eval-rmse:0.000417	train-rmse:0.000422
# [713]	eval-rmse:0.000416	train-rmse:0.000422
# [714]	eval-rmse:0.000415	train-rmse:0.000421
# [715]	eval-rmse:0.000414	train-rmse:0.00042
# [716]	eval-rmse:0.000413	train-rmse:0.000419
# [717]	eval-rmse:0.000412	train-rmse:0.000418
# [718]	eval-rmse:0.000411	train-rmse:0.000417
# [719]	eval-rmse:0.000411	train-rmse:0.000416
# [720]	eval-rmse:0.00041	train-rmse:0.000415
# [721]	eval-rmse:0.000409	train-rmse:0.000415
# [722]	eval-rmse:0.000408	train-rmse:0.000414
# [723]	eval-rmse:0.000407	train-rmse:0.000413
# [724]	eval-rmse:0.000406	train-rmse:0.000412
# [725]	eval-rmse:0.000406	train-rmse:0.000411
# [726]	eval-rmse:0.000405	train-rmse:0.000411
# [727]	eval-rmse:0.000404	train-rmse:0.00041
# [728]	eval-rmse:0.000403	train-rmse:0.000409
# [729]	eval-rmse:0.000403	train-rmse:0.000408
# [730]	eval-rmse:0.000402	train-rmse:0.000408
# [731]	eval-rmse:0.000401	train-rmse:0.000407
# [732]	eval-rmse:0.0004	train-rmse:0.000406
# [733]	eval-rmse:0.0004	train-rmse:0.000406
# [734]	eval-rmse:0.000399	train-rmse:0.000405
# [735]	eval-rmse:0.000398	train-rmse:0.000404
# [736]	eval-rmse:0.000398	train-rmse:0.000404
# [737]	eval-rmse:0.000397	train-rmse:0.000403
# [738]	eval-rmse:0.000397	train-rmse:0.000402
# [739]	eval-rmse:0.000396	train-rmse:0.000402
# [740]	eval-rmse:0.000395	train-rmse:0.000401
# [741]	eval-rmse:0.000395	train-rmse:0.000401
# [742]	eval-rmse:0.000394	train-rmse:0.0004
# [743]	eval-rmse:0.000394	train-rmse:0.0004
# [744]	eval-rmse:0.000393	train-rmse:0.000399
# [745]	eval-rmse:0.000392	train-rmse:0.000398
# [746]	eval-rmse:0.000392	train-rmse:0.000398
# [747]	eval-rmse:0.000391	train-rmse:0.000397
# [748]	eval-rmse:0.000391	train-rmse:0.000397
# [749]	eval-rmse:0.00039	train-rmse:0.000396
# [750]	eval-rmse:0.00039	train-rmse:0.000396
# [751]	eval-rmse:0.000389	train-rmse:0.000395
# [752]	eval-rmse:0.000389	train-rmse:0.000395
# [753]	eval-rmse:0.000388	train-rmse:0.000394
# [754]	eval-rmse:0.000388	train-rmse:0.000394
# [755]	eval-rmse:0.000387	train-rmse:0.000394
# [756]	eval-rmse:0.000387	train-rmse:0.000393
# [757]	eval-rmse:0.000387	train-rmse:0.000393
# [758]	eval-rmse:0.000386	train-rmse:0.000392
# [759]	eval-rmse:0.000386	train-rmse:0.000392
# [760]	eval-rmse:0.000385	train-rmse:0.000392
# [761]	eval-rmse:0.000385	train-rmse:0.000391
# [762]	eval-rmse:0.000384	train-rmse:0.000391
# [763]	eval-rmse:0.000384	train-rmse:0.00039
# [764]	eval-rmse:0.000384	train-rmse:0.00039
# [765]	eval-rmse:0.000383	train-rmse:0.00039
# [766]	eval-rmse:0.000383	train-rmse:0.000389
# [767]	eval-rmse:0.000382	train-rmse:0.000389
# [768]	eval-rmse:0.000382	train-rmse:0.000389
# [769]	eval-rmse:0.000382	train-rmse:0.000388
# [770]	eval-rmse:0.000381	train-rmse:0.000388
# [771]	eval-rmse:0.000381	train-rmse:0.000388
# [772]	eval-rmse:0.000381	train-rmse:0.000387
# [773]	eval-rmse:0.00038	train-rmse:0.000387
# [774]	eval-rmse:0.00038	train-rmse:0.000387
# [775]	eval-rmse:0.00038	train-rmse:0.000386
# [776]	eval-rmse:0.000379	train-rmse:0.000386
# [777]	eval-rmse:0.000379	train-rmse:0.000386
# [778]	eval-rmse:0.000379	train-rmse:0.000386
# [779]	eval-rmse:0.000379	train-rmse:0.000385
# [780]	eval-rmse:0.000378	train-rmse:0.000385
# [781]	eval-rmse:0.000378	train-rmse:0.000385
# [782]	eval-rmse:0.000378	train-rmse:0.000384
# [783]	eval-rmse:0.000377	train-rmse:0.000384
# [784]	eval-rmse:0.000377	train-rmse:0.000384
# [785]	eval-rmse:0.000377	train-rmse:0.000384
# [786]	eval-rmse:0.000377	train-rmse:0.000383
# [787]	eval-rmse:0.000376	train-rmse:0.000383
# [788]	eval-rmse:0.000376	train-rmse:0.000383
# [789]	eval-rmse:0.000376	train-rmse:0.000383
# [790]	eval-rmse:0.000376	train-rmse:0.000382
# [791]	eval-rmse:0.000375	train-rmse:0.000382
# [792]	eval-rmse:0.000375	train-rmse:0.000382
# [793]	eval-rmse:0.000375	train-rmse:0.000382
# [794]	eval-rmse:0.000375	train-rmse:0.000382
# [795]	eval-rmse:0.000375	train-rmse:0.000381
# [796]	eval-rmse:0.000374	train-rmse:0.000381
# [797]	eval-rmse:0.000374	train-rmse:0.000381
# [798]	eval-rmse:0.000374	train-rmse:0.000381
# [799]	eval-rmse:0.000374	train-rmse:0.000381
# [800]	eval-rmse:0.000373	train-rmse:0.00038
# [801]	eval-rmse:0.000373	train-rmse:0.00038
# [802]	eval-rmse:0.000373	train-rmse:0.00038
# [803]	eval-rmse:0.000373	train-rmse:0.00038
# [804]	eval-rmse:0.000373	train-rmse:0.00038
# [805]	eval-rmse:0.000373	train-rmse:0.00038
# [806]	eval-rmse:0.000372	train-rmse:0.000379
# [807]	eval-rmse:0.000372	train-rmse:0.000379
# [808]	eval-rmse:0.000372	train-rmse:0.000379
# [809]	eval-rmse:0.000372	train-rmse:0.000379
# [810]	eval-rmse:0.000372	train-rmse:0.000379
# [811]	eval-rmse:0.000372	train-rmse:0.000379
# [812]	eval-rmse:0.000371	train-rmse:0.000378
# [813]	eval-rmse:0.000371	train-rmse:0.000378
# [814]	eval-rmse:0.000371	train-rmse:0.000378
# [815]	eval-rmse:0.000371	train-rmse:0.000378
# [816]	eval-rmse:0.000371	train-rmse:0.000378
# [817]	eval-rmse:0.000371	train-rmse:0.000378
# [818]	eval-rmse:0.00037	train-rmse:0.000378
# [819]	eval-rmse:0.00037	train-rmse:0.000378
# [820]	eval-rmse:0.00037	train-rmse:0.000377
# [821]	eval-rmse:0.00037	train-rmse:0.000377
# [822]	eval-rmse:0.00037	train-rmse:0.000377
# [823]	eval-rmse:0.00037	train-rmse:0.000377
# [824]	eval-rmse:0.00037	train-rmse:0.000377
# [825]	eval-rmse:0.00037	train-rmse:0.000377
# [826]	eval-rmse:0.000369	train-rmse:0.000376
# [827]	eval-rmse:0.000369	train-rmse:0.000376
# [828]	eval-rmse:0.000369	train-rmse:0.000376
# [829]	eval-rmse:0.000369	train-rmse:0.000376
# [830]	eval-rmse:0.000369	train-rmse:0.000376
# [831]	eval-rmse:0.000369	train-rmse:0.000376
# [832]	eval-rmse:0.000369	train-rmse:0.000376
# [833]	eval-rmse:0.000369	train-rmse:0.000376
# [834]	eval-rmse:0.000369	train-rmse:0.000376
# [835]	eval-rmse:0.000368	train-rmse:0.000376
# [836]	eval-rmse:0.000368	train-rmse:0.000375
# [837]	eval-rmse:0.000368	train-rmse:0.000375
# [838]	eval-rmse:0.000368	train-rmse:0.000375
# [839]	eval-rmse:0.000368	train-rmse:0.000375
# [840]	eval-rmse:0.000368	train-rmse:0.000375
# [841]	eval-rmse:0.000368	train-rmse:0.000375
# [842]	eval-rmse:0.000368	train-rmse:0.000375
# [843]	eval-rmse:0.000368	train-rmse:0.000375
# [844]	eval-rmse:0.000368	train-rmse:0.000375
# [845]	eval-rmse:0.000367	train-rmse:0.000375
# [846]	eval-rmse:0.000367	train-rmse:0.000375
# [847]	eval-rmse:0.000367	train-rmse:0.000375
# [848]	eval-rmse:0.000367	train-rmse:0.000375
# [849]	eval-rmse:0.000367	train-rmse:0.000374
# [850]	eval-rmse:0.000367	train-rmse:0.000374
# [851]	eval-rmse:0.000367	train-rmse:0.000374
# [852]	eval-rmse:0.000367	train-rmse:0.000374
# [853]	eval-rmse:0.000367	train-rmse:0.000374
# [854]	eval-rmse:0.000367	train-rmse:0.000374
# [855]	eval-rmse:0.000367	train-rmse:0.000374
# [856]	eval-rmse:0.000367	train-rmse:0.000374
# [857]	eval-rmse:0.000367	train-rmse:0.000374
# [858]	eval-rmse:0.000367	train-rmse:0.000374
# [859]	eval-rmse:0.000366	train-rmse:0.000374
# [860]	eval-rmse:0.000366	train-rmse:0.000374
# [861]	eval-rmse:0.000366	train-rmse:0.000374
# [862]	eval-rmse:0.000366	train-rmse:0.000374
# [863]	eval-rmse:0.000366	train-rmse:0.000374
# [864]	eval-rmse:0.000366	train-rmse:0.000374
# [865]	eval-rmse:0.000366	train-rmse:0.000374
# [866]	eval-rmse:0.000366	train-rmse:0.000373
# [867]	eval-rmse:0.000366	train-rmse:0.000373
# [868]	eval-rmse:0.000366	train-rmse:0.000373
# [869]	eval-rmse:0.000366	train-rmse:0.000373
# [870]	eval-rmse:0.000366	train-rmse:0.000373
# [871]	eval-rmse:0.000366	train-rmse:0.000373
# [872]	eval-rmse:0.000366	train-rmse:0.000373
# [873]	eval-rmse:0.000366	train-rmse:0.000373
# [874]	eval-rmse:0.000366	train-rmse:0.000373
# [875]	eval-rmse:0.000366	train-rmse:0.000373
# [876]	eval-rmse:0.000365	train-rmse:0.000373
# [877]	eval-rmse:0.000365	train-rmse:0.000373
# [878]	eval-rmse:0.000365	train-rmse:0.000373
# [879]	eval-rmse:0.000365	train-rmse:0.000373
# [880]	eval-rmse:0.000365	train-rmse:0.000373
# [881]	eval-rmse:0.000365	train-rmse:0.000373
# [882]	eval-rmse:0.000365	train-rmse:0.000373
# [883]	eval-rmse:0.000365	train-rmse:0.000373
# [884]	eval-rmse:0.000365	train-rmse:0.000373
# [885]	eval-rmse:0.000365	train-rmse:0.000373
# [886]	eval-rmse:0.000365	train-rmse:0.000373
# [887]	eval-rmse:0.000365	train-rmse:0.000373
# [888]	eval-rmse:0.000365	train-rmse:0.000373
# [889]	eval-rmse:0.000365	train-rmse:0.000373
# [890]	eval-rmse:0.000365	train-rmse:0.000373
# [891]	eval-rmse:0.000365	train-rmse:0.000372
# [892]	eval-rmse:0.000365	train-rmse:0.000372
# [893]	eval-rmse:0.000365	train-rmse:0.000372
# [894]	eval-rmse:0.000365	train-rmse:0.000372
# [895]	eval-rmse:0.000365	train-rmse:0.000372
# [896]	eval-rmse:0.000365	train-rmse:0.000372
# [897]	eval-rmse:0.000365	train-rmse:0.000372
# [898]	eval-rmse:0.000365	train-rmse:0.000372
# [899]	eval-rmse:0.000365	train-rmse:0.000372
# [900]	eval-rmse:0.000365	train-rmse:0.000372
# [901]	eval-rmse:0.000365	train-rmse:0.000372
# [902]	eval-rmse:0.000364	train-rmse:0.000372
# [903]	eval-rmse:0.000364	train-rmse:0.000372
# [904]	eval-rmse:0.000364	train-rmse:0.000372
# [905]	eval-rmse:0.000364	train-rmse:0.000372
# [906]	eval-rmse:0.000364	train-rmse:0.000372
# [907]	eval-rmse:0.000364	train-rmse:0.000372
# [908]	eval-rmse:0.000364	train-rmse:0.000372
# [909]	eval-rmse:0.000364	train-rmse:0.000372
# [910]	eval-rmse:0.000364	train-rmse:0.000372
# [911]	eval-rmse:0.000364	train-rmse:0.000372
# [912]	eval-rmse:0.000364	train-rmse:0.000372
# [913]	eval-rmse:0.000364	train-rmse:0.000372
# [914]	eval-rmse:0.000364	train-rmse:0.000372
# [915]	eval-rmse:0.000364	train-rmse:0.000372
# [916]	eval-rmse:0.000364	train-rmse:0.000372
# [917]	eval-rmse:0.000364	train-rmse:0.000372
# [918]	eval-rmse:0.000364	train-rmse:0.000372
# [919]	eval-rmse:0.000364	train-rmse:0.000372
# [920]	eval-rmse:0.000364	train-rmse:0.000372
# [921]	eval-rmse:0.000364	train-rmse:0.000372
# [922]	eval-rmse:0.000364	train-rmse:0.000372
# [923]	eval-rmse:0.000364	train-rmse:0.000372
# [924]	eval-rmse:0.000364	train-rmse:0.000372
# [925]	eval-rmse:0.000364	train-rmse:0.000372
# [926]	eval-rmse:0.000364	train-rmse:0.000372
# [927]	eval-rmse:0.000364	train-rmse:0.000372
# [928]	eval-rmse:0.000364	train-rmse:0.000372
# [929]	eval-rmse:0.000364	train-rmse:0.000372
# [930]	eval-rmse:0.000364	train-rmse:0.000372
# [931]	eval-rmse:0.000364	train-rmse:0.000372
# [932]	eval-rmse:0.000364	train-rmse:0.000372
# [933]	eval-rmse:0.000364	train-rmse:0.000372
# [934]	eval-rmse:0.000364	train-rmse:0.000372
# [935]	eval-rmse:0.000364	train-rmse:0.000372
# [936]	eval-rmse:0.000364	train-rmse:0.000372
# [937]	eval-rmse:0.000364	train-rmse:0.000372
# [938]	eval-rmse:0.000364	train-rmse:0.000372
# [939]	eval-rmse:0.000364	train-rmse:0.000372
# [940]	eval-rmse:0.000364	train-rmse:0.000372
# [941]	eval-rmse:0.000364	train-rmse:0.000372
# [942]	eval-rmse:0.000364	train-rmse:0.000372
# [943]	eval-rmse:0.000364	train-rmse:0.000372
# [944]	eval-rmse:0.000364	train-rmse:0.000371
# [945]	eval-rmse:0.000364	train-rmse:0.000371
# [946]	eval-rmse:0.000364	train-rmse:0.000371
# [947]	eval-rmse:0.000364	train-rmse:0.000371
# [948]	eval-rmse:0.000364	train-rmse:0.000371
# [949]	eval-rmse:0.000364	train-rmse:0.000371
# [950]	eval-rmse:0.000364	train-rmse:0.000371
# [951]	eval-rmse:0.000364	train-rmse:0.000371
# [952]	eval-rmse:0.000364	train-rmse:0.000371
# [953]	eval-rmse:0.000364	train-rmse:0.000371
# [954]	eval-rmse:0.000364	train-rmse:0.000371
# [955]	eval-rmse:0.000363	train-rmse:0.000371
# [956]	eval-rmse:0.000363	train-rmse:0.000371
# [957]	eval-rmse:0.000363	train-rmse:0.000371
# [958]	eval-rmse:0.000363	train-rmse:0.000371
# [959]	eval-rmse:0.000363	train-rmse:0.000371
# [960]	eval-rmse:0.000363	train-rmse:0.000371
# [961]	eval-rmse:0.000363	train-rmse:0.000371
# [962]	eval-rmse:0.000363	train-rmse:0.000371
# [963]	eval-rmse:0.000363	train-rmse:0.000371
# [964]	eval-rmse:0.000363	train-rmse:0.000371
# [965]	eval-rmse:0.000363	train-rmse:0.000371
# [966]	eval-rmse:0.000363	train-rmse:0.000371
# [967]	eval-rmse:0.000363	train-rmse:0.000371
# [968]	eval-rmse:0.000363	train-rmse:0.000371
# [969]	eval-rmse:0.000363	train-rmse:0.000371
# [970]	eval-rmse:0.000363	train-rmse:0.000371
# [971]	eval-rmse:0.000363	train-rmse:0.000371
# [972]	eval-rmse:0.000363	train-rmse:0.000371
# [973]	eval-rmse:0.000363	train-rmse:0.000371
# [974]	eval-rmse:0.000363	train-rmse:0.000371
# [975]	eval-rmse:0.000363	train-rmse:0.000371
# [976]	eval-rmse:0.000363	train-rmse:0.000371
# [977]	eval-rmse:0.000363	train-rmse:0.000371
# [978]	eval-rmse:0.000363	train-rmse:0.000371
# [979]	eval-rmse:0.000363	train-rmse:0.000371
# [980]	eval-rmse:0.000363	train-rmse:0.000371
# [981]	eval-rmse:0.000363	train-rmse:0.000371
# [982]	eval-rmse:0.000363	train-rmse:0.000371
# [983]	eval-rmse:0.000363	train-rmse:0.000371
# [984]	eval-rmse:0.000363	train-rmse:0.000371
# [985]	eval-rmse:0.000363	train-rmse:0.000371
# [986]	eval-rmse:0.000363	train-rmse:0.000371
# [987]	eval-rmse:0.000363	train-rmse:0.000371
# [988]	eval-rmse:0.000363	train-rmse:0.000371
# [989]	eval-rmse:0.000363	train-rmse:0.000371
# [990]	eval-rmse:0.000363	train-rmse:0.000371
# [991]	eval-rmse:0.000363	train-rmse:0.000371
# [992]	eval-rmse:0.000363	train-rmse:0.000371
# [993]	eval-rmse:0.000363	train-rmse:0.000371
# [994]	eval-rmse:0.000363	train-rmse:0.000371
# [995]	eval-rmse:0.000363	train-rmse:0.000371
# [996]	eval-rmse:0.000363	train-rmse:0.000371
# [997]	eval-rmse:0.000363	train-rmse:0.000371
# [998]	eval-rmse:0.000363	train-rmse:0.000371
# [999]	eval-rmse:0.000363	train-rmse:0.000371
# [1000]	eval-rmse:0.000363	train-rmse:0.000371
# [1001]	eval-rmse:0.000363	train-rmse:0.000371
# [1002]	eval-rmse:0.000363	train-rmse:0.000371
# [1003]	eval-rmse:0.000363	train-rmse:0.000371
# [1004]	eval-rmse:0.000363	train-rmse:0.000371
# [1005]	eval-rmse:0.000363	train-rmse:0.000371
# [1006]	eval-rmse:0.000363	train-rmse:0.000371
# [1007]	eval-rmse:0.000363	train-rmse:0.000371
# [1008]	eval-rmse:0.000363	train-rmse:0.000371
# [1009]	eval-rmse:0.000363	train-rmse:0.000371
# [1010]	eval-rmse:0.000363	train-rmse:0.000371
# [1011]	eval-rmse:0.000363	train-rmse:0.000371
# [1012]	eval-rmse:0.000363	train-rmse:0.000371
# [1013]	eval-rmse:0.000363	train-rmse:0.000371
# [1014]	eval-rmse:0.000363	train-rmse:0.000371
# [1015]	eval-rmse:0.000363	train-rmse:0.000371
# [1016]	eval-rmse:0.000363	train-rmse:0.000371
# [1017]	eval-rmse:0.000363	train-rmse:0.000371
# [1018]	eval-rmse:0.000363	train-rmse:0.000371
# [1019]	eval-rmse:0.000363	train-rmse:0.000371
# [1020]	eval-rmse:0.000363	train-rmse:0.000371
# [1021]	eval-rmse:0.000363	train-rmse:0.000371
# [1022]	eval-rmse:0.000363	train-rmse:0.000371
# [1023]	eval-rmse:0.000363	train-rmse:0.000371
# [1024]	eval-rmse:0.000363	train-rmse:0.000371
# [1025]	eval-rmse:0.000363	train-rmse:0.000371
# [1026]	eval-rmse:0.000363	train-rmse:0.000371
# [1027]	eval-rmse:0.000363	train-rmse:0.000371
# [1028]	eval-rmse:0.000363	train-rmse:0.000371
# [1029]	eval-rmse:0.000363	train-rmse:0.000371
# [1030]	eval-rmse:0.000363	train-rmse:0.000371
# [1031]	eval-rmse:0.000363	train-rmse:0.000371
# [1032]	eval-rmse:0.000363	train-rmse:0.000371
# [1033]	eval-rmse:0.000363	train-rmse:0.000371
# [1034]	eval-rmse:0.000363	train-rmse:0.000371
# [1035]	eval-rmse:0.000363	train-rmse:0.000371
# [1036]	eval-rmse:0.000363	train-rmse:0.000371
# [1037]	eval-rmse:0.000363	train-rmse:0.000371
# [1038]	eval-rmse:0.000363	train-rmse:0.000371
# [1039]	eval-rmse:0.000363	train-rmse:0.000371
# [1040]	eval-rmse:0.000363	train-rmse:0.000371
# [1041]	eval-rmse:0.000363	train-rmse:0.000371
# [1042]	eval-rmse:0.000363	train-rmse:0.000371
# [1043]	eval-rmse:0.000363	train-rmse:0.000371
# [1044]	eval-rmse:0.000363	train-rmse:0.000371
# [1045]	eval-rmse:0.000363	train-rmse:0.000371
# [1046]	eval-rmse:0.000363	train-rmse:0.000371
# [1047]	eval-rmse:0.000363	train-rmse:0.000371
# [1048]	eval-rmse:0.000363	train-rmse:0.000371
# [1049]	eval-rmse:0.000363	train-rmse:0.000371
# [1050]	eval-rmse:0.000363	train-rmse:0.000371
# [1051]	eval-rmse:0.000363	train-rmse:0.000371
# [1052]	eval-rmse:0.000363	train-rmse:0.000371
# [1053]	eval-rmse:0.000363	train-rmse:0.000371
# [1054]	eval-rmse:0.000363	train-rmse:0.000371
# [1055]	eval-rmse:0.000363	train-rmse:0.000371
# [1056]	eval-rmse:0.000363	train-rmse:0.000371
# [1057]	eval-rmse:0.000363	train-rmse:0.000371
# [1058]	eval-rmse:0.000363	train-rmse:0.000371
# [1059]	eval-rmse:0.000363	train-rmse:0.000371
# [1060]	eval-rmse:0.000363	train-rmse:0.000371
# [1061]	eval-rmse:0.000363	train-rmse:0.000371
# [1062]	eval-rmse:0.000363	train-rmse:0.000371
# ...
# [1599]	eval-rmse:0.000363	train-rmse:0.000371
# [1600]	eval-rmse:0.000363	train-rmse:0.000371
# [1601]	eval-rmse:0.000363	train-rmse:0.000371
# [1602]	eval-rmse:0.000363	train-rmse:0.000371
# [1603]	eval-rmse:0.000363	train-rmse:0.000371
# [1604]	eval-rmse:0.000363	train-rmse:0.000371
# [1605]	eval-rmse:0.000363	train-rmse:0.000371
# [1606]	eval-rmse:0.000363	train-rmse:0.000371
# [1607]	eval-rmse:0.000363	train-rmse:0.000371
# [1608]	eval-rmse:0.000363	train-rmse:0.000371
# [1609]	eval-rmse:0.000363	train-rmse:0.000371
# [1610]	eval-rmse:0.000363	train-rmse:0.000371
# [1611]	eval-rmse:0.000363	train-rmse:0.000371
# [1612]	eval-rmse:0.000363	train-rmse:0.000371
# [1613]	eval-rmse:0.000363	train-rmse:0.000371
# [1614]	eval-rmse:0.000363	train-rmse:0.000371
# [1615]	eval-rmse:0.000363	train-rmse:0.000371
# [1616]	eval-rmse:0.000363	train-rmse:0.000371
# [1617]	eval-rmse:0.000363	train-rmse:0.000371
# [1618]	eval-rmse:0.000363	train-rmse:0.000371
# [1619]	eval-rmse:0.000363	train-rmse:0.000371
# [1620]	eval-rmse:0.000363	train-rmse:0.000371
# [1621]	eval-rmse:0.000363	train-rmse:0.000371
# [1622]	eval-rmse:0.000363	train-rmse:0.000371
# [1623]	eval-rmse:0.000363	train-rmse:0.000371
# [1624]	eval-rmse:0.000363	train-rmse:0.000371
# [1625]	eval-rmse:0.000363	train-rmse:0.000371
# [1626]	eval-rmse:0.000363	train-rmse:0.000371
# [1627]	eval-rmse:0.000363	train-rmse:0.000371
# [1628]	eval-rmse:0.000363	train-rmse:0.000371
# [1629]	eval-rmse:0.000363	train-rmse:0.000371
# [1630]	eval-rmse:0.000363	train-rmse:0.000371
# [1631]	eval-rmse:0.000363	train-rmse:0.000371
# [1632]	eval-rmse:0.000363	train-rmse:0.000371
# [1633]	eval-rmse:0.000363	train-rmse:0.000371
# [1634]	eval-rmse:0.000363	train-rmse:0.000371
# [1635]	eval-rmse:0.000363	train-rmse:0.000371
# [1636]	eval-rmse:0.000363	train-rmse:0.000371
# [1637]	eval-rmse:0.000363	train-rmse:0.000371
# [1638]	eval-rmse:0.000363	train-rmse:0.000371
# [1639]	eval-rmse:0.000363	train-rmse:0.000371
# [1640]	eval-rmse:0.000363	train-rmse:0.000371
# [1641]	eval-rmse:0.000363	train-rmse:0.000371
# [1642]	eval-rmse:0.000363	train-rmse:0.000371
# [1643]	eval-rmse:0.000363	train-rmse:0.000371
# [1644]	eval-rmse:0.000363	train-rmse:0.000371
# [1645]	eval-rmse:0.000363	train-rmse:0.000371
# [1646]	eval-rmse:0.000363	train-rmse:0.000371
# [1647]	eval-rmse:0.000363	train-rmse:0.000371
# [1648]	eval-rmse:0.000363	train-rmse:0.000371
# [1649]	eval-rmse:0.000363	train-rmse:0.000371
# [1650]	eval-rmse:0.000363	train-rmse:0.000371
# [1651]	eval-rmse:0.000363	train-rmse:0.000371
# [1652]	eval-rmse:0.000363	train-rmse:0.000371
# [1653]	eval-rmse:0.000363	train-rmse:0.000371
# [1654]	eval-rmse:0.000363	train-rmse:0.000371
# [1655]	eval-rmse:0.000363	train-rmse:0.000371
# [1656]	eval-rmse:0.000363	train-rmse:0.000371
# [1657]	eval-rmse:0.000363	train-rmse:0.000371
# [1658]	eval-rmse:0.000363	train-rmse:0.000371
# [1659]	eval-rmse:0.000363	train-rmse:0.000371
# [1660]	eval-rmse:0.000363	train-rmse:0.000371
# [1661]	eval-rmse:0.000363	train-rmse:0.000371
# [1662]	eval-rmse:0.000363	train-rmse:0.000371
# [1663]	eval-rmse:0.000363	train-rmse:0.000371
# [1664]	eval-rmse:0.000363	train-rmse:0.000371
# [1665]	eval-rmse:0.000363	train-rmse:0.000371
# [1666]	eval-rmse:0.000363	train-rmse:0.000371
# [1667]	eval-rmse:0.000363	train-rmse:0.000371
# [1668]	eval-rmse:0.000363	train-rmse:0.000371
# [1669]	eval-rmse:0.000363	train-rmse:0.000371
# [1670]	eval-rmse:0.000363	train-rmse:0.000371
# [1671]	eval-rmse:0.000363	train-rmse:0.000371
# [1672]	eval-rmse:0.000363	train-rmse:0.000371
# [1673]	eval-rmse:0.000363	train-rmse:0.000371
# [1674]	eval-rmse:0.000363	train-rmse:0.000371
# [1675]	eval-rmse:0.000363	train-rmse:0.000371
# [1676]	eval-rmse:0.000363	train-rmse:0.000371
# [1677]	eval-rmse:0.000363	train-rmse:0.000371
# [1678]	eval-rmse:0.000363	train-rmse:0.000371
# [1679]	eval-rmse:0.000363	train-rmse:0.000371
# [1680]	eval-rmse:0.000363	train-rmse:0.000371
# [1681]	eval-rmse:0.000363	train-rmse:0.000371
# [1682]	eval-rmse:0.000363	train-rmse:0.000371
# [1683]	eval-rmse:0.000363	train-rmse:0.000371
# [1684]	eval-rmse:0.000363	train-rmse:0.000371
# [1685]	eval-rmse:0.000363	train-rmse:0.000371
# [1686]	eval-rmse:0.000363	train-rmse:0.000371
# [1687]	eval-rmse:0.000363	train-rmse:0.000371
# [1688]	eval-rmse:0.000363	train-rmse:0.000371
# [1689]	eval-rmse:0.000363	train-rmse:0.000371
# [1690]	eval-rmse:0.000363	train-rmse:0.000371
# [1691]	eval-rmse:0.000363	train-rmse:0.000371
# [1692]	eval-rmse:0.000363	train-rmse:0.000371
# [1693]	eval-rmse:0.000363	train-rmse:0.000371
# [1694]	eval-rmse:0.000363	train-rmse:0.000371
# [1695]	eval-rmse:0.000363	train-rmse:0.000371
# [1696]	eval-rmse:0.000363	train-rmse:0.000371
# [1697]	eval-rmse:0.000363	train-rmse:0.000371
# [1698]	eval-rmse:0.000363	train-rmse:0.000371
# [1699]	eval-rmse:0.000363	train-rmse:0.000371
# [1700]	eval-rmse:0.000363	train-rmse:0.000371
# [1701]	eval-rmse:0.000363	train-rmse:0.000371
# [1702]	eval-rmse:0.000363	train-rmse:0.000371
# [1703]	eval-rmse:0.000363	train-rmse:0.000371
# [1704]	eval-rmse:0.000363	train-rmse:0.000371
# [1705]	eval-rmse:0.000363	train-rmse:0.000371
# [1706]	eval-rmse:0.000363	train-rmse:0.000371
# [1707]	eval-rmse:0.000363	train-rmse:0.000371
# [1708]	eval-rmse:0.000363	train-rmse:0.000371
# [1709]	eval-rmse:0.000363	train-rmse:0.000371
# [1710]	eval-rmse:0.000363	train-rmse:0.000371
# [1711]	eval-rmse:0.000363	train-rmse:0.000371
# [1712]	eval-rmse:0.000363	train-rmse:0.000371
# [1713]	eval-rmse:0.000363	train-rmse:0.000371
# [1714]	eval-rmse:0.000363	train-rmse:0.000371
# [1715]	eval-rmse:0.000363	train-rmse:0.000371
# [1716]	eval-rmse:0.000363	train-rmse:0.000371
# [1717]	eval-rmse:0.000363	train-rmse:0.000371
# [1718]	eval-rmse:0.000363	train-rmse:0.000371
# [1719]	eval-rmse:0.000363	train-rmse:0.000371
# [1720]	eval-rmse:0.000363	train-rmse:0.000371
# [1721]	eval-rmse:0.000363	train-rmse:0.000371
# [1722]	eval-rmse:0.000363	train-rmse:0.000371
# [1723]	eval-rmse:0.000363	train-rmse:0.000371
# [1724]	eval-rmse:0.000363	train-rmse:0.000371
# [1725]	eval-rmse:0.000363	train-rmse:0.000371
# [1726]	eval-rmse:0.000363	train-rmse:0.000371
# [1727]	eval-rmse:0.000363	train-rmse:0.000371
# [1728]	eval-rmse:0.000363	train-rmse:0.000371
# [1729]	eval-rmse:0.000363	train-rmse:0.000371
# [1730]	eval-rmse:0.000363	train-rmse:0.000371
# [1731]	eval-rmse:0.000363	train-rmse:0.000371
# [1732]	eval-rmse:0.000363	train-rmse:0.000371
# [1733]	eval-rmse:0.000363	train-rmse:0.000371
# [1734]	eval-rmse:0.000363	train-rmse:0.000371
# [1735]	eval-rmse:0.000363	train-rmse:0.000371
# [1736]	eval-rmse:0.000363	train-rmse:0.000371
# [1737]	eval-rmse:0.000363	train-rmse:0.000371
# [1738]	eval-rmse:0.000363	train-rmse:0.000371
# [1739]	eval-rmse:0.000363	train-rmse:0.000371
# [1740]	eval-rmse:0.000363	train-rmse:0.000371
# [1741]	eval-rmse:0.000363	train-rmse:0.000371
# [1742]	eval-rmse:0.000363	train-rmse:0.000371
# [1743]	eval-rmse:0.000363	train-rmse:0.000371
# [1744]	eval-rmse:0.000363	train-rmse:0.000371
# [1745]	eval-rmse:0.000363	train-rmse:0.000371
# [1746]	eval-rmse:0.000363	train-rmse:0.000371
# [1747]	eval-rmse:0.000363	train-rmse:0.000371
# [1748]	eval-rmse:0.000363	train-rmse:0.000371
# [1749]	eval-rmse:0.000363	train-rmse:0.000371
# [1750]	eval-rmse:0.000363	train-rmse:0.000371
# [1751]	eval-rmse:0.000363	train-rmse:0.000371
# [1752]	eval-rmse:0.000363	train-rmse:0.000371
# [1753]	eval-rmse:0.000363	train-rmse:0.000371
# [1754]	eval-rmse:0.000363	train-rmse:0.000371
# [1755]	eval-rmse:0.000363	train-rmse:0.000371
# [1756]	eval-rmse:0.000363	train-rmse:0.000371
# [1757]	eval-rmse:0.000363	train-rmse:0.000371
# [1758]	eval-rmse:0.000363	train-rmse:0.000371
# [1759]	eval-rmse:0.000363	train-rmse:0.000371
# [1760]	eval-rmse:0.000363	train-rmse:0.000371
# [1761]	eval-rmse:0.000363	train-rmse:0.000371
# [1762]	eval-rmse:0.000363	train-rmse:0.000371
# [1763]	eval-rmse:0.000363	train-rmse:0.000371
# [1764]	eval-rmse:0.000363	train-rmse:0.000371
# [1765]	eval-rmse:0.000363	train-rmse:0.000371
# [1766]	eval-rmse:0.000363	train-rmse:0.000371
# [1767]	eval-rmse:0.000363	train-rmse:0.000371
# [1768]	eval-rmse:0.000363	train-rmse:0.000371
# [1769]	eval-rmse:0.000363	train-rmse:0.000371
# [1770]	eval-rmse:0.000363	train-rmse:0.000371
# [1771]	eval-rmse:0.000363	train-rmse:0.000371
# [1772]	eval-rmse:0.000363	train-rmse:0.000371
# [1773]	eval-rmse:0.000363	train-rmse:0.000371
# [1774]	eval-rmse:0.000363	train-rmse:0.000371
# [1775]	eval-rmse:0.000363	train-rmse:0.000371
# [1776]	eval-rmse:0.000363	train-rmse:0.000371
# [1777]	eval-rmse:0.000363	train-rmse:0.000371
# [1778]	eval-rmse:0.000363	train-rmse:0.000371
# [1779]	eval-rmse:0.000363	train-rmse:0.000371
# [1780]	eval-rmse:0.000363	train-rmse:0.000371
# [1781]	eval-rmse:0.000363	train-rmse:0.000371
# [1782]	eval-rmse:0.000363	train-rmse:0.000371
# [1783]	eval-rmse:0.000363	train-rmse:0.000371
# [1784]	eval-rmse:0.000363	train-rmse:0.000371
# [1785]	eval-rmse:0.000363	train-rmse:0.000371
# [1786]	eval-rmse:0.000363	train-rmse:0.000371
# [1787]	eval-rmse:0.000363	train-rmse:0.000371
# [1788]	eval-rmse:0.000363	train-rmse:0.000371
# [1789]	eval-rmse:0.000363	train-rmse:0.000371
# [1790]	eval-rmse:0.000363	train-rmse:0.000371
# [1791]	eval-rmse:0.000363	train-rmse:0.000371
# [1792]	eval-rmse:0.000363	train-rmse:0.000371
# [1793]	eval-rmse:0.000363	train-rmse:0.000371
# [1794]	eval-rmse:0.000363	train-rmse:0.000371
# [1795]	eval-rmse:0.000363	train-rmse:0.000371
# [1796]	eval-rmse:0.000363	train-rmse:0.000371
# [1797]	eval-rmse:0.000363	train-rmse:0.000371
# [1798]	eval-rmse:0.000363	train-rmse:0.000371
# [1799]	eval-rmse:0.000363	train-rmse:0.000371
# [1800]	eval-rmse:0.000363	train-rmse:0.000371
# [1801]	eval-rmse:0.000363	train-rmse:0.000371
# [1802]	eval-rmse:0.000363	train-rmse:0.000371
# [1803]	eval-rmse:0.000363	train-rmse:0.000371
# [1804]	eval-rmse:0.000363	train-rmse:0.000371
# [1805]	eval-rmse:0.000363	train-rmse:0.000371
# [1806]	eval-rmse:0.000363	train-rmse:0.000371
# [1807]	eval-rmse:0.000363	train-rmse:0.000371
# [1808]	eval-rmse:0.000363	train-rmse:0.000371
# [1809]	eval-rmse:0.000363	train-rmse:0.000371
# [1810]	eval-rmse:0.000363	train-rmse:0.000371
# [1811]	eval-rmse:0.000363	train-rmse:0.000371
# [1812]	eval-rmse:0.000363	train-rmse:0.000371
# [1813]	eval-rmse:0.000363	train-rmse:0.000371
# [1814]	eval-rmse:0.000363	train-rmse:0.000371
# [1815]	eval-rmse:0.000363	train-rmse:0.000371
# [1816]	eval-rmse:0.000363	train-rmse:0.000371
# [1817]	eval-rmse:0.000363	train-rmse:0.000371
# [1818]	eval-rmse:0.000363	train-rmse:0.000371
# [1819]	eval-rmse:0.000363	train-rmse:0.000371
# [1820]	eval-rmse:0.000363	train-rmse:0.000371
# [1821]	eval-rmse:0.000363	train-rmse:0.000371
# [1822]	eval-rmse:0.000363	train-rmse:0.000371
# [1823]	eval-rmse:0.000363	train-rmse:0.000371
# [1824]	eval-rmse:0.000363	train-rmse:0.000371
# [1825]	eval-rmse:0.000363	train-rmse:0.000371
# [1826]	eval-rmse:0.000363	train-rmse:0.000371
# [1827]	eval-rmse:0.000363	train-rmse:0.000371
# [1828]	eval-rmse:0.000363	train-rmse:0.000371
# [1829]	eval-rmse:0.000363	train-rmse:0.000371
# [1830]	eval-rmse:0.000363	train-rmse:0.000371
# [1831]	eval-rmse:0.000363	train-rmse:0.000371
# [1832]	eval-rmse:0.000363	train-rmse:0.000371
# [1833]	eval-rmse:0.000363	train-rmse:0.000371
# [1834]	eval-rmse:0.000363	train-rmse:0.000371
# [1835]	eval-rmse:0.000363	train-rmse:0.000371
# [1836]	eval-rmse:0.000363	train-rmse:0.000371
# [1837]	eval-rmse:0.000363	train-rmse:0.000371
# [1838]	eval-rmse:0.000363	train-rmse:0.000371
# [1839]	eval-rmse:0.000363	train-rmse:0.000371
# [1840]	eval-rmse:0.000363	train-rmse:0.000371
# [1841]	eval-rmse:0.000363	train-rmse:0.000371
# [1842]	eval-rmse:0.000363	train-rmse:0.000371
# [1843]	eval-rmse:0.000363	train-rmse:0.000371
# [1844]	eval-rmse:0.000363	train-rmse:0.000371
# [1845]	eval-rmse:0.000363	train-rmse:0.000371
# [1846]	eval-rmse:0.000363	train-rmse:0.000371
# [1847]	eval-rmse:0.000363	train-rmse:0.000371
# [1848]	eval-rmse:0.000363	train-rmse:0.000371
# [1849]	eval-rmse:0.000363	train-rmse:0.000371
# [1850]	eval-rmse:0.000363	train-rmse:0.000371
# [1851]	eval-rmse:0.000363	train-rmse:0.000371
# [1852]	eval-rmse:0.000363	train-rmse:0.000371
# [1853]	eval-rmse:0.000363	train-rmse:0.000371
# [1854]	eval-rmse:0.000363	train-rmse:0.000371
# [1855]	eval-rmse:0.000363	train-rmse:0.000371
# [1856]	eval-rmse:0.000363	train-rmse:0.000371
# [1857]	eval-rmse:0.000363	train-rmse:0.000371
# [1858]	eval-rmse:0.000363	train-rmse:0.000371
# [1859]	eval-rmse:0.000363	train-rmse:0.000371
# [1860]	eval-rmse:0.000363	train-rmse:0.000371
# [1861]	eval-rmse:0.000363	train-rmse:0.000371
# [1862]	eval-rmse:0.000363	train-rmse:0.000371
# [1863]	eval-rmse:0.000363	train-rmse:0.000371
# [1864]	eval-rmse:0.000363	train-rmse:0.000371
# [1865]	eval-rmse:0.000363	train-rmse:0.000371
# [1866]	eval-rmse:0.000363	train-rmse:0.000371
# [1867]	eval-rmse:0.000363	train-rmse:0.000371
# [1868]	eval-rmse:0.000363	train-rmse:0.000371
# [1869]	eval-rmse:0.000363	train-rmse:0.000371
# [1870]	eval-rmse:0.000363	train-rmse:0.000371
# [1871]	eval-rmse:0.000363	train-rmse:0.000371
# [1872]	eval-rmse:0.000363	train-rmse:0.000371
# [1873]	eval-rmse:0.000363	train-rmse:0.000371
# [1874]	eval-rmse:0.000363	train-rmse:0.000371
# [1875]	eval-rmse:0.000363	train-rmse:0.000371
# [1876]	eval-rmse:0.000363	train-rmse:0.000371
# [1877]	eval-rmse:0.000363	train-rmse:0.000371
# [1878]	eval-rmse:0.000363	train-rmse:0.000371
# [1879]	eval-rmse:0.000363	train-rmse:0.000371
# [1880]	eval-rmse:0.000363	train-rmse:0.000371
# [1881]	eval-rmse:0.000363	train-rmse:0.000371
# [1882]	eval-rmse:0.000363	train-rmse:0.000371
# [1883]	eval-rmse:0.000363	train-rmse:0.000371
# [1884]	eval-rmse:0.000363	train-rmse:0.000371
# [1885]	eval-rmse:0.000363	train-rmse:0.000371
# [1886]	eval-rmse:0.000363	train-rmse:0.000371
# [1887]	eval-rmse:0.000363	train-rmse:0.000371
# [1888]	eval-rmse:0.000363	train-rmse:0.000371
# [1889]	eval-rmse:0.000363	train-rmse:0.000371
# [1890]	eval-rmse:0.000363	train-rmse:0.000371
# [1891]	eval-rmse:0.000363	train-rmse:0.000371
# [1892]	eval-rmse:0.000363	train-rmse:0.000371
# [1893]	eval-rmse:0.000363	train-rmse:0.000371
# [1894]	eval-rmse:0.000363	train-rmse:0.000371
# [1895]	eval-rmse:0.000363	train-rmse:0.000371
# [1896]	eval-rmse:0.000363	train-rmse:0.000371
# [1897]	eval-rmse:0.000363	train-rmse:0.000371
# [1898]	eval-rmse:0.000363	train-rmse:0.000371
# [1899]	eval-rmse:0.000363	train-rmse:0.000371
# [1900]	eval-rmse:0.000363	train-rmse:0.000371
# [1901]	eval-rmse:0.000363	train-rmse:0.000371
# [1902]	eval-rmse:0.000363	train-rmse:0.000371
# [1903]	eval-rmse:0.000363	train-rmse:0.000371
# [1904]	eval-rmse:0.000363	train-rmse:0.000371
# [1905]	eval-rmse:0.000363	train-rmse:0.000371
# [1906]	eval-rmse:0.000363	train-rmse:0.000371
# [1907]	eval-rmse:0.000363	train-rmse:0.000371
# [1908]	eval-rmse:0.000363	train-rmse:0.000371
# [1909]	eval-rmse:0.000363	train-rmse:0.000371
# [1910]	eval-rmse:0.000363	train-rmse:0.000371
# [1911]	eval-rmse:0.000363	train-rmse:0.000371
# [1912]	eval-rmse:0.000363	train-rmse:0.000371
# [1913]	eval-rmse:0.000363	train-rmse:0.000371
# [1914]	eval-rmse:0.000363	train-rmse:0.000371
# [1915]	eval-rmse:0.000363	train-rmse:0.000371
# [1916]	eval-rmse:0.000363	train-rmse:0.000371
# [1917]	eval-rmse:0.000363	train-rmse:0.000371
# [1918]	eval-rmse:0.000363	train-rmse:0.000371
# [1919]	eval-rmse:0.000363	train-rmse:0.000371
# [1920]	eval-rmse:0.000363	train-rmse:0.000371
# [1921]	eval-rmse:0.000363	train-rmse:0.000371
# [1922]	eval-rmse:0.000363	train-rmse:0.000371
# [1923]	eval-rmse:0.000363	train-rmse:0.000371
# [1924]	eval-rmse:0.000363	train-rmse:0.000371
# [1925]	eval-rmse:0.000363	train-rmse:0.000371
# [1926]	eval-rmse:0.000363	train-rmse:0.000371
# [1927]	eval-rmse:0.000363	train-rmse:0.000371
# [1928]	eval-rmse:0.000363	train-rmse:0.000371
# [1929]	eval-rmse:0.000363	train-rmse:0.000371
# [1930]	eval-rmse:0.000363	train-rmse:0.000371
# [1931]	eval-rmse:0.000363	train-rmse:0.000371
# [1932]	eval-rmse:0.000363	train-rmse:0.000371
# [1933]	eval-rmse:0.000363	train-rmse:0.000371
# [1934]	eval-rmse:0.000363	train-rmse:0.000371
# [1935]	eval-rmse:0.000363	train-rmse:0.000371
# [1936]	eval-rmse:0.000363	train-rmse:0.000371
# [1937]	eval-rmse:0.000363	train-rmse:0.000371
# [1938]	eval-rmse:0.000363	train-rmse:0.000371
# [1939]	eval-rmse:0.000363	train-rmse:0.000371
# [1940]	eval-rmse:0.000363	train-rmse:0.000371
# [1941]	eval-rmse:0.000363	train-rmse:0.000371
# [1942]	eval-rmse:0.000363	train-rmse:0.000371
# [1943]	eval-rmse:0.000363	train-rmse:0.000371
# [1944]	eval-rmse:0.000363	train-rmse:0.000371
# Stopping. Best iteration:
# [944]	eval-rmse:0.000364	train-rmse:0.000371

# %%
# あとはファイル作成
import csv
with open("predict_result_data_house.csv", "w") as f:
  # dtest = xgb.DMatrix(test_x)
  # my_submission = pd.DataFrame()
  # my_submission["Id"] = test_ID
  # my_submission["SalePrice"] = np.exp(bst.predict(dtest))
  
  writer = csv.writer(f, lineterminator='\n')
  # writer.writerow(["Id", "SalePrice"])
  writer.writerow(["Id", "SalePrice"])  
  for pid, survived in zip(test_data[:,0].astype(int), Y_pred.astype(int)):
      writer.writerow([pid, survived])

print('done');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-1fa5ea6cf6de> in <module>()
#       9   # writer.writerow(["Id", "SalePrice"])
#      10   writer.writerow(["Id", "SalePrice"])
# ---> 11   for pid, survived in zip(test_data[:,0].astype(int), Y_pred.astype(int)):
#      12       writer.writerow([pid, survived])
#      13
#
# NameError: name 'test_data' is not defined
